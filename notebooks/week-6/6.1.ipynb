# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

from time import gmtime, strftime
import os
import re
import pickle
import random
import sys
# Out:
# Using TensorFlow backend.

# %%
# load ascii text from file
filename = "data/obama.txt"
raw_text = open(filename).read()

# get rid of any characters other than letters, numbers, 
# and a few special characters
raw_text = re.sub('[^\nA-Za-z0-9 ,.:;?!-]+', '', raw_text)

# convert all text to lowercase
raw_text = raw_text.lower()

n_chars = len(raw_text)
print "length of text:", n_chars
print "text preview:", raw_text[:500]
# Out:
# length of text: 18355
# text preview: wherever i go these days, at home or abroad, people ask me the same question: what is happening in the american political system? how has a country that has benefited perhaps more than any other from immigration, trade and technological innovation suddenly developed a strain of anti-immigrant, anti-innovation protectionism? why have some on the far left and even more on the far right embraced a crude populism that promises a return to a past that is not possible to restore and that, for most ame

# %%
# extract all unique characters in the text
chars = sorted(list(set(raw_text)))
n_vocab = len(chars)
print "number of unique characters found:", n_vocab

# create mapping of characters to integers and back
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# test our mapping
print 'a', "- maps to ->", char_to_int["a"]
print 25, "- maps to ->", int_to_char[25]
# Out:
# number of unique characters found: 44
# a - maps to -> 18
# 25 - maps to -> h

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100

inputs = []
outputs = []

for i in range(0, n_chars - seq_length, 1):
    inputs.append(raw_text[i:i + seq_length])
    outputs.append(raw_text[i + seq_length])
    
n_sequences = len(inputs)
print "Total sequences: ", n_sequences
# Out:
# Total sequences:  18255

# %%
indeces = range(len(inputs))
random.shuffle(indeces)

inputs = [inputs[x] for x in indeces]
outputs = [outputs[x] for x in indeces]

# %%
print inputs[0], "-->", outputs[0]
# Out:
# ve and guaranteed sick days, as well as greater access to high-quality child care and early learning --> ,

# %%
# create two empty numpy array with the proper dimensions
X = np.zeros((n_sequences, seq_length, n_vocab), dtype=np.bool)
y = np.zeros((n_sequences, n_vocab), dtype=np.bool)

# iterate over the data and build up the X and y data sets
# by setting the appropriate indices to 1 in each one-hot vector
for i, example in enumerate(inputs):
    for t, char in enumerate(example):
        X[i, t, char_to_int[char]] = 1
    y[i, char_to_int[outputs[i]]] = 1
    
print 'X dims -->', X.shape
print 'y dims -->', y.shape
# Out:
# X dims --> (18255, 100, 44)
# y dims --> (18255, 44)

# %%
# define the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=False, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.50))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate(sentence, prediction_length=50, diversity=0.35):
    print '----- diversity:', diversity 

    generated = sentence
    sys.stdout.write(generated)

    # iterate over number of characters requested
    for i in range(prediction_length):
        
        # build up sequence data from current sentence
        x = np.zeros((1, X.shape[1], X.shape[2]))
        for t, char in enumerate(sentence):
            x[0, t, char_to_int[char]] = 1.

        # use trained model to return probability distribution
        # for next character based on input sequence
        preds = model.predict(x, verbose=0)[0]
        
        # use sample() function to sample next character 
        # based on probability distribution and desired diversity
        next_index = sample(preds, diversity)
        
        # convert integer to character
        next_char = int_to_char[next_index]

        # add new character to generated text
        generated += next_char
        
        # delete the first character from beginning of sentance, 
        # and add new caracter to the end. This will form the 
        # input sequence for the next predicted character.
        sentence = sentence[1:] + next_char

        # print results to screen
        sys.stdout.write(next_char)
        sys.stdout.flush()
    print

# %%
filepath="-basic_LSTM.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
epochs = 50
prediction_length = 100

for iteration in range(epochs):
    
    print 'epoch:', iteration + 1, '/', epochs
    model.fit(X, y, validation_split=0.2, batch_size=256, nb_epoch=1, callbacks=callbacks_list)
    
    # get random starting point for seed
    start_index = random.randint(0, len(raw_text) - seq_length - 1)
    # extract seed sequence from raw text
    seed = raw_text[start_index: start_index + seq_length]
    
    print '----- generating with seed:', seed
    
    for diversity in [0.5, 1.2]:
        generate(seed, prediction_length, diversity)
# Out:
# epoch: 1 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 78s - loss: 3.2221 - val_loss: 2.9590
# ----- generating with seed:  a long-term decline in participation among prime-age workers see chart 3. in 1953, just 3 of men be
# ----- diversity: 0.5
#  a long-term decline in participation among prime-age workers see chart 3. in 1953, just 3 of men bet on l i  trda net  ie treai tetaee  nlcea e   0om en stke  p o e d ine he eoes d  pr rheicco ieetl
# ----- diversity: 1.2
#  a long-term decline in participation among prime-age workers see chart 3. in 1953, just 3 of men be ui uwwg8cdrpsve -la o o o;egneo timeo-tsoczrbixe qmrn edlt
# ul nt..0d
# rztt aa eefeecatounair t erhu.
# epoch: 2 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 79s - loss: 3.0273 - val_loss: 2.9241
# ----- generating with seed: le and supportive of long-term growth, including more capital for american banks, less reliance on s
# ----- diversity: 0.5
# le and supportive of long-term growth, including more capital for american banks, less reliance on ses ee  oet ten ae eo  enpetes   eee   it e  e  eeoeagen e e n me ensssan   o osa d r oa   e lo  ea e
# ----- diversity: 1.2
# le and supportive of long-term growth, including more capital for american banks, less reliance on san tzfsezarmre eexufnut uva yht eh uauorcf eago ci lr  ov ei6momf;t t etpnt  ra aiai:sf
# a 5gfepiedl
# epoch: 3 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 80s - loss: 2.9724 - val_loss: 2.8600
# ----- generating with seed: in participation among prime-age workers see chart 3. in 1953, just 3 of men between 25 and 54 years
# ----- diversity: 0.5
# in participation among prime-age workers see chart 3. in 1953, just 3 of men between 25 and 54 yearsrt   cnt e les  o on re ta . aser tnor  st  i oeie n y dn eonn tn ne t t  ter r eo  deo r hto sn   o
# ----- diversity: 1.2
# in participation among prime-age workers see chart 3. in 1953, just 3 of men between 25 and 54 years hvec  efr ep hnns  rspc-r m ttsetbnnd.viee  aeur udqylvdi ne,,tse he thet l  h. : hsbutcoorstoh tbb
# epoch: 4 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 84s - loss: 2.8850 - val_loss: 2.7666
# ----- generating with seed: vity growth and rising inequality have resulted in slower income growth for low- and middle-income f
# ----- diversity: 0.5
# vity growth and rising inequality have resulted in slower income growth for low- and middle-income ftor iret tne fnon n aoche aosncons rh th aauta s en ce regt t s too t fo sm hni t e r eorut es te om
# ----- diversity: 1.2
# vity growth and rising inequality have resulted in slower income growth for low- and middle-income fsr n ovrd efeo
# o fboc
# r rneh so tls nveleodnt oesps thee4scmhu 1e rnv
# eds nto2,oen- 2xoh itoa hte  u
# epoch: 5 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 87s - loss: 2.7802 - val_loss: 2.6441
# ----- generating with seed:  been put to rest. america has cut energy-sector emissions by 6, even as our economy has grown by 11
# ----- diversity: 0.5
#  been put to rest. america has cut energy-sector emissions by 6, even as our economy has grown by 11 mes s eng  teren  na ier to e pes not ro ee a inan ot ea the he is torr re in  n aed tin inceracoet
# ----- diversity: 1.2
#  been put to rest. america has cut energy-sector emissions by 6, even as our economy has grown by 11aihta xx- osj ug9n rti59sri hebraaoicdrpue ve a oabee qo r4auynw bgiiesnin ull weat tils togce  av a
# epoch: 6 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 82s - loss: 2.6661 - val_loss: 2.5547
# ----- generating with seed: ort pay their workers up to 18 more on average than companies that do not, according to a report by
# ----- diversity: 0.5
# ort pay their workers up to 18 more on average than companies that do not, according to a report by omalate  erete tin te nerefone eon od the chan tealid oseole reued oont ooptwore cos ton ang ine tor
# ----- diversity: 1.2
# ort pay their workers up to 18 more on average than companies that do not, according to a report by nmarf,ine, tolrmcts -lnl, onfatiou wviar vlx uesolurttmaess ties varncpbaptfnesucinovoygthaa rrilstn
# epoch: 7 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 83s - loss: 2.5911 - val_loss: 2.4815
# ----- generating with seed:  in participation among prime-age workers see chart 3. in 1953, just 3 of men between 25 and 54 year
# ----- diversity: 0.5
#  in participation among prime-age workers see chart 3. in 1953, just 3 of men between 25 and 54 yeare the ta ther ald and s the ore th mere tior the ter bot e can an far as the the tis femene faris th
# ----- diversity: 1.2
#  in participation among prime-age workers see chart 3. in 1953, just 3 of men between 25 and 54 yeardel, cfomile tt porethcwes con cysechpancoess aro ditw, tino  imayo rawhe te kgorrethguhocanmteuwice
# epoch: 8 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 82s - loss: 2.5294 - val_loss: 2.4267
# ----- generating with seed: rdless of how we divide up the pie.
#
# a major source of the recent productivity slowdown has been a s
# ----- diversity: 0.5
# rdless of how we divide up the pie.
#
# a major source of the recent productivity slowdown has been a s an  aond an itil ta alo te att ate ind tar os ani an ae the the t ine an lle the in ate to at in re
# ----- diversity: 1.2
# rdless of how we divide up the pie.
#
# a major source of the recent productivity slowdown has been a se dor sol miga stoil iq8issdinmif:ah y ate hogirint fekim revadlsgare coropsw aos er dtelged ss funa
# epoch: 9 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 84s - loss: 2.4867 - val_loss: 2.3819
# ----- generating with seed:  technology allows anyone with a smartphone to see how the most privileged live. expectations rise f
# ----- diversity: 0.5
#  technology allows anyone with a smartphone to see how the most privileged live. expectations rise fand the an  foatid ne the to ras on ore aat e-gate fore the the the the the ares ou the are ind to b
# ----- diversity: 1.2
#  technology allows anyone with a smartphone to see how the most privileged live. expectations rise faforglort grdte u8the we-orimns lalt outtg noravhisl sry pereebd rolis alisacx eriwh tud
# meitt at ar
# epoch: 10 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 84s - loss: 2.4475 - val_loss: 2.3510
# ----- generating with seed:  and businesses alike.
#
# second, alongside slowing productivity, inequality has risen in most advance
# ----- diversity: 0.5
#  and businesses alike.
#
# second, alongside slowing productivity, inequality has risen in most advancengetar contising or inece ingall the ingsuled sore thon an acintelis ad the the tha the the coure th
# ----- diversity: 1.2
#  and businesses alike.
#
# second, alongside slowing productivity, inequality has risen in most advancecsevycor acanno wimelten. lm wbototatrlu btupulticobey yoraissinnor.eciontw-x deslylee m.acevatez6sy
# epoch: 11 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 80s - loss: 2.4160 - val_loss: 2.3232
# ----- generating with seed: litical system? how has a country that has benefited perhaps more than any other from immigration, t
# ----- diversity: 0.5
# litical system? how has a country that has benefited perhaps more than any other from immigration, the an the the tor the cant or the thas ton the gatit an as for thans icongtom ricann the aont en mor
# ----- diversity: 1.2
# litical system? how has a country that has benefited perhaps more than any other from immigration, ti ananvwes adcpoyparusd tha draig end therqyisloo okey ncamhit s te seavit eofroncead tutt-taod esa8
# epoch: 12 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 90s - loss: 2.3941 - val_loss: 2.3007
# ----- generating with seed: y a greater degree of social interaction between employees at all levels at church, at their childre
# ----- diversity: 0.5
# y a greater degree of social interaction between employees at all levels at church, at their childreng farte the the pborese the the the tor er an te here the toe ame wore and engand the the ser sore
# ----- diversity: 1.2
# y a greater degree of social interaction between employees at all levels at church, at their childrecr cirsaysing
# ascstitot ith mpeubl taaus ,feinltigsshy eroull fe fhotmeress. bfy mapt ho1x ub pdcimd
# epoch: 13 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 84s - loss: 2.3613 - val_loss: 2.2771
# ----- generating with seed: ncial institutions accountable, so their customers get loans they can repay with clear terms up-fron
# ----- diversity: 0.5
# ncial institutions accountable, so their customers get loans they can repay with clear terms up-frone sore and the tatet fat here the pord the eon al sore are pate polet aan rore lanin ar and patibis
# ----- diversity: 1.2
# ncial institutions accountable, so their customers get loans they can repay with clear terms up-froncer piademrto. whog alsy cinger ter aerbe te ove oc tititse ra fatysofis mor ob sivetrcemut inap ina
# epoch: 14 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 84s - loss: 2.3395 - val_loss: 2.2535
# ----- generating with seed: kers were constrained by a greater degree of social interaction between employees at all levels at c
# ----- diversity: 0.5
# kers were constrained by a greater degree of social interaction between employees at all levels at core the fort an to  ave of bution the bale the ins and the butale and tha e on athe wore the ton bou
# ----- diversity: 1.2
# kers were constrained by a greater degree of social interaction between employees at all levels at con sto. le ano , oblpcarmat dh omveufdrmat, s abn3ecrebitmes anmsat meovmthird tisr, coveawt inia.,
# epoch: 15 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 83s - loss: 2.3126 - val_loss: 2.2389
# ----- generating with seed:  of applying their talents to innovating in the real economy. and the financial crisis of 2008 only
# ----- diversity: 0.5
#  of applying their talents to innovating in the real economy. and the financial crisis of 2008 only seromes an recerenges the werend te the that ilde ant pares ane the ared and the baled and and taple
# ----- diversity: 1.2
#  of applying their talents to innovating in the real economy. and the financial crisis of 2008 only cavt. gualr ho bes ouble, t who?sitn dratr cerajy de omis yxwtiich o2ceugengite1.
#
# om cofyameebryaal
# epoch: 16 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 88s - loss: 2.2972 - val_loss: 2.2252
# ----- generating with seed: ce that have won bipartisan support would also improve participation, if enacted.
#
# building a sturdi
# ----- diversity: 0.5
# ce that have won bipartisan support would also improve participation, if enacted.
#
# building a sturdite the wors the eromar and ar ind thes tor the con the en and the in guthe to perining tha the to to
# ----- diversity: 1.2
# ce that have won bipartisan support would also improve participation, if enacted.
#
# building a sturdis tha bmemenscesr gomerton chevoprewng on ancposscftartsans w
# hcr eenamir af unecmisalgwkr a1c cesin
# epoch: 17 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 79s - loss: 2.2751 - val_loss: 2.2046
# ----- generating with seed: ity controls as much wealth as the other 99 will never be stable. gaps between rich and poor are not
# ----- diversity: 0.5
# ity controls as much wealth as the other 99 will never be stable. gaps between rich and poor are note that in the thal the s rowe roan furlton the thes the pore sing in prole the se wat in thare cinat
# ----- diversity: 1.2
# ity controls as much wealth as the other 99 will never be stable. gaps between rich and poor are nots jacd womertoasslyss werilwes inewi
# te and th4 lorveros ind e8fasint oulusion bikes the gredewt tha
# epoch: 18 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 79s - loss: 2.2509 - val_loss: 2.2011
# ----- generating with seed: inequality has risen in most advanced economies, with that increase most pronounced in the united st
# ----- diversity: 0.5
# inequality has risen in most advanced economies, with that increase most pronounced in the united st at care the the gporeng the coroulis wo the bast the ronces of ard wher grertees the that ar the me
# ----- diversity: 1.2
# inequality has risen in most advanced economies, with that increase most pronounced in the united stolmricant
# ;ditei07 civamte.:
#  noweeng thatmefol peissisen ay fherdels. frs 8mm theut le dovery tnes
# epoch: 19 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 77s - loss: 2.2417 - val_loss: 2.1877
# ----- generating with seed:  ways to keep more americans in the labour market when they fall on hard times. these include provid
# ----- diversity: 0.5
#  ways to keep more americans in the labour market when they fall on hard times. these include provid won cond the prosere of erorse the tout restore the wors mens to bere gand ice ales y oure ant ad t
# ----- diversity: 1.2
#  ways to keep more americans in the labour market when they fall on hard times. these include providu fpreawirlhaxginc a;sionoy ecncor fr alkitr hatjer bep-uod on wsot hile
#  sm rkele s. bidicig pamyer
# epoch: 20 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 113s - loss: 2.2145 - val_loss: 2.1735
# ----- generating with seed: estment partnership with the eu. these agreements, and stepped-up trade enforcement, will level the
# ----- diversity: 0.5
# estment partnership with the eu. these agreements, and stepped-up trade enforcement, will level the gat on an alitix an ion and the and cosit in but and in sion arith th wor fore fore the promons the
# ----- diversity: 1.2
# estment partnership with the eu. these agreements, and stepped-up trade enforcement, will level the nfmilyumign.in, to
# uthomth ay bor chorus of ncoud s. ahincecunuld- ad lobust. anc nravfut pion caf t
# epoch: 21 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 89s - loss: 2.2053 - val_loss: 2.1549
# ----- generating with seed: e argument that the game is rigged. but amid this understandable frustration, much of it fanned by p
# ----- diversity: 0.5
# e argument that the game is rigged. but amid this understandable frustration, much of it fanned by porel and alr and the reent piond in wor thas parg ald hos corsing the bore to and bo were the pranci
# ----- diversity: 1.2
# e argument that the game is rigged. but amid this understandable frustration, much of it fanned by pokt thm raliean wic
# by pytduferuve rechven eunth7l cosktodever. momeatithis of mress thes promte tun
# epoch: 22 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 79s - loss: 2.1986 - val_loss: 2.1409
# ----- generating with seed: measure expended substantial energy. i did not get some of the expansions i sought and congress forc
# ----- diversity: 0.5
# measure expended substantial energy. i did not get some of the expansions i sought and congress forc in the  hol ed and the for care in the the the the the wes and tion at in and celthat hand that on
# ----- diversity: 1.2
# measure expended substantial energy. i did not get some of the expansions i sought and congress forcuif it mano t e; soslelmesrr gqcal lomissumato oais tha, rie tu4 aket eherundicsios, m oalre trlo0g
#
# epoch: 23 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 83s - loss: 2.1692 - val_loss: 2.1323
# ----- generating with seed: le frustration, much of it fanned by politicians who would actually make the problem worse rather th
# ----- diversity: 0.5
# le frustration, much of it fanned by politicians who would actually make the problem worse rather that the and oum wor is ne cale to wes sent an fore farle colout and ther ind anit on duclition the do
# ----- diversity: 1.2
# le frustration, much of it fanned by politicians who would actually make the problem worse rather that hisantomesuring hevoofcon puprore-lhape diset. d otkart j5ii., devior prliun merora,-trak. cal py
# epoch: 24 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 80s - loss: 2.1535 - val_loss: 2.1188
# ----- generating with seed: undation
# finally, the financial crisis painfully underscored the need for a more resilient economy,
# ----- diversity: 0.5
# undation
# finally, the financial crisis painfully underscored the need for a more resilient economy, more that endalising fhand none in weme the and in ame inersadith an pooully coule paon and recand a
# ----- diversity: 1.2
# undation
# finally, the financial crisis painfully underscored the need for a more resilient economy, th in haile clysadeng fatllgiry,-ucfnrebp. ey bekene t; ensadilnsoule-fezarbe uthit posc. tueurkanr
# epoch: 25 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 75s - loss: 2.1394 - val_loss: 2.1182
# ----- generating with seed: on the far left and even more on the far right embraced a crude populism that promises a return to a
# ----- diversity: 0.5
# on the far left and even more on the far right embraced a crude populism that promises a return to and thas ersare of indreanis ane reour and tor that and the wors and the fors to the gromers goancore
# ----- diversity: 1.2
# on the far left and even more on the far right embraced a crude populism that promises a return to automestul reelisoto tasdsicniost acedudingacbed bosid we opu hard wfhotsor s of thivitastirilas cofr
# epoch: 26 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 77s - loss: 2.1210 - val_loss: 2.1056
# ----- generating with seed: ne. increasing access to high-quality community colleges, proven job-training models and help findin
# ----- diversity: 0.5
# ne. increasing access to high-quality community colleges, proven job-training models and help finding the tor tho gove the iver the and whe dengrect an or wore sore the pore to ast andrecons be and al
# ----- diversity: 1.2
# ne. increasing access to high-quality community colleges, proven job-training models and help findinertililisipciss the f po conexttad b. isecmestho giyod fwerseble tn. theancrsina is-monst fhincprein
# epoch: 27 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 2.1055 - val_loss: 2.0952
# ----- generating with seed: ee market only thrives when there are rules to guard against systemic failure and ensure fair compet
# ----- diversity: 0.5
# ee market only thrives when there are rules to guard against systemic failure and ensure fair compet of aalle and le mong mes rout, ronden thea the bute and fear and erond the dent pions se wor amer a
# ----- diversity: 1.2
# ee market only thrives when there are rules to guard against systemic failure and ensure fair compet of suverge, whexutweun dang ijubut fe bro? mrathedr funs rtepao li act fazhlg p equiss it sot pally
# epoch: 28 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 2.0880 - val_loss: 2.0965
# ----- generating with seed: radox that defines our world today. the world is more prosperous than ever before and yet our societ
# ----- diversity: 0.5
# radox that defines our world today. the world is more prosperous than ever before and yet our societ of the omeiting that on the incally but fating an weree conome at all gecincales mat  eron bite and
# ----- diversity: 1.2
# radox that defines our world today. the world is more prosperous than ever before and yet our societ. xh slelpybye. wissawey aa dekthe thefadulting thiyy icnommst1,eos wtot lpoiziss ary my ber, recy,
# epoch: 29 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 2.0777 - val_loss: 2.0871
# ----- generating with seed:  comprehensive rewriting of the rules of the financial system since the 1930s, as well as reforming
# ----- diversity: 0.5
#  comprehensive rewriting of the rules of the financial system since the 1930s, as well as reforming in hise. in wile the rage in the add the mare in the averees for and bat in thal weng and al anderin
# ----- diversity: 1.2
#  comprehensive rewriting of the rules of the financial system since the 1930s, as well as reforming eubio0stt angyamever conthatso ipwry abstey rogs bhepes andudewiingaly. t 150 , h rese  mabcol ancer
# epoch: 30 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 75s - loss: 2.0616 - val_loss: 2.0796
# ----- generating with seed: zens is vital. curbs to entitlement growth that build on the affordable care act s progress in reduc
# ----- diversity: 0.5
# zens is vital. curbs to entitlement growth that build on the affordable care act s progress in reduct chase the pout fort ou thit wald rese the the prower the the dome the singe that probe the woll to
# ----- diversity: 1.2
# zens is vital. curbs to entitlement growth that build on the affordable care act s progress in reduce, bo fanlaw and ry to  olp; ant ines anmratignt ly mos hwheg ndest j el tye. the tup-bigliad 19 0be
# epoch: 31 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 77s - loss: 2.0490 - val_loss: 2.0731
# ----- generating with seed:  rising inequality, ensuring that everyone who wants a job can get one and building a resilient econ
# ----- diversity: 0.5
#  rising inequality, ensuring that everyone who wants a job can get one and building a resilient economy serped the conegre and tee parcing  hereate rod ency an erate the wern to bat ans the pove the e
# ----- diversity: 1.2
#  rising inequality, ensuring that everyone who wants a job can get one and building a resilient econhapttugt, idxarens s sektofay yomhr t4d t-ow-ine macd. pibhiiny dat jof are o sind wan os t o- tha f
# epoch: 32 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 2.0266 - val_loss: 2.0642
# ----- generating with seed: f stabilising our economy. unfortunately, good economics can be overridden by bad politics. my admin
# ----- diversity: 0.5
# f stabilising our economy. unfortunately, good economics can be overridden by bad politics. my adminicin wally the probst on by te and ans umero pare the toun inst am al e soferecon the wentiles the t
# ----- diversity: 1.2
# f stabilising our economy. unfortunately, good economics can be overridden by bad politics. my adminimcm.siming, ytinst iof verpe won wehpechty ig. w0ilts yrugi. fysecas ly our fierch icb lun mecf rmo
# epoch: 33 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 2.0074 - val_loss: 2.0640
# ----- generating with seed: g the consumer financial protection bureau to hold financial institutions accountable, so their cust
# ----- diversity: 0.5
# g the consumer financial protection bureau to hold financial institutions accountable, so their custore the ald soreent. tit on the aversent and ed pore to were on the 200 qual the recens deamess and
# ----- diversity: 1.2
# g the consumer financial protection bureau to hold financial institutions accountable, so their custool bult bagit yfincs ann it chondequiins fand isventicani-ingspasth ged thaal lexeesad ou nom ssapl
# epoch: 34 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 75s - loss: 1.9915 - val_loss: 2.0573
# ----- generating with seed: r fair share, tax changes enacted during my administration have increased the share of income receiv
# ----- diversity: 0.5
# r fair share, tax changes enacted during my administration have increased the share of income receive that an the ware denoy the enof tho erono ned fore serice for mere adich the past and amerincans b
# ----- diversity: 1.2
# r fair share, tax changes enacted during my administration have increased the share of income receivimiss rifo lutins moase lostuobad. ty -malyimsems, wiy mle ay fos caheun in coa1 ter eved taxhat ddr
# epoch: 35 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 1.9825 - val_loss: 2.0462
# ----- generating with seed: his will not lead to broadly shared prosperity and growth. economists have long recognised that mark
# ----- diversity: 0.5
# his will not lead to broadly shared prosperity and growth. economists have long recognised that marker and the provicing in ars conter of ouc desing en weet seen and tor thin the borestor ard conting
# ----- diversity: 1.2
# his will not lead to broadly shared prosperity and growth. economists have long recognised that markadm thataclifalre
# give raver repeore poorke thoo7 thes ustrapring th tweatinds ffied vore more doars
# epoch: 36 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 73s - loss: 1.9692 - val_loss: 2.0453
# ----- generating with seed: ildhood education to improving high schools, making college more affordable and expanding high-quali
# ----- diversity: 0.5
# ildhood education to improving high schools, making college more affordable and expanding high-qualitith the stoupe al the wing to eat of the the prowth in wore the  and towe nof of icand in whal dean
# ----- diversity: 1.2
# ildhood education to improving high schools, making college more affordable and expanding high-qualitwin9 sattarin veriby somoimwt am rem.ititgas that hal int1inlalily  aris-oplodcent, 2
# 0u groaddep s
# epoch: 37 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 1.9545 - val_loss: 2.0428
# ----- generating with seed: ian sentiment in the late 19th and early 20th centuries, and any number of eras in which americans w
# ----- diversity: 0.5
# ian sentiment in the late 19th and early 20th centuries, and any number of eras in which americans wat all to t o prove the more the woult anto to the sut the athe thac songer in rece ses on hes thes
# ----- diversity: 1.2
# ian sentiment in the late 19th and early 20th centuries, and any number of eras in which americans whage taiceara dofcow shpout mut, caces war erehsitee ta ianqures morcouut om roancorex in rofixteno
# epoch: 38 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 75s - loss: 1.9399 - val_loss: 2.0454
# ----- generating with seed: ly and rent-seeking that this newspaper has documented, the failure of businesses to take into accou
# ----- diversity: 0.5
# ly and rent-seeking that this newspaper has documented, the failure of businesses to take into accoust at ous the doust doprore the pondertist houd des and ancin in ard the fort farle contad the farle
# ----- diversity: 1.2
# ly and rent-seeking that this newspaper has documented, the failure of businesses to take into accounttiers ingorgimer family ypyimdst ta y. ins. get pet lepsevan twi u to bes rover pas
# os f-com an g
# epoch: 39 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 72s - loss: 1.9140 - val_loss: 2.0420
# ----- generating with seed: roductivity, inequality has risen in most advanced economies, with that increase most pronounced in
# ----- diversity: 0.5
# roductivity, inequality has risen in most advanced economies, with that increase most pronounced in the andeded corces and atimers and the ballse for econome the wat the aic poting whan andiry and cha
# ----- diversity: 1.2
# roductivity, inequality has risen in most advanced economies, with that increase most pronounced in eeuthrycth or  huleq ansucec nor d yeres conr fussigl gom wigkert veyalterel groved tafislinaing eau
# epoch: 40 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 72s - loss: 1.8949 - val_loss: 2.0404
# ----- generating with seed: ng to our children, particularly for infrastructure; and a political system so partisan that previou
# ----- diversity: 0.5
# ng to our children, particularly for infrastructure; and a political system so partisan that previound in the poonted that in the tat rese ame tha dess to the arcalise the buting the cand rise share w
# ----- diversity: 1.2
# ng to our children, particularly for infrastructure; and a political system so partisan that previougto ses hawish inkecabiins
# sawhas wero nesimivecint cenpeyet en. gowees alsingew the aud-ravien fur
# epoch: 41 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 72s - loss: 1.8807 - val_loss: 2.0390
# ----- generating with seed: conomists have long recognised that markets, left to their own devices, can fail. this can happen th
# ----- diversity: 0.5
# conomists have long recognised that markets, left to their own devices, can fail. this can happen that the inconcist contime that s oul the ges res and of ars aren the secono cecond bit the provinting
# ----- diversity: 1.2
# conomists have long recognised that markets, left to their own devices, can fail. this can happen theol exconnomicith nraconcomon savertp lunppare, puvcrosm nad bo5lreby tuced bom souich l-somhes tha
# epoch: 42 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 77s - loss: 1.8726 - val_loss: 2.0350
# ----- generating with seed: nomy prematurely by threatening a historic debt default. my successors should not have to fight for
# ----- diversity: 0.5
# nomy prematurely by threatening a historic debt default. my successors should not have to fight for cofrerte the workers we lave ta in all in rovenitis for wer comenting tha dested by for ensine soule
# ----- diversity: 1.2
# nomy prematurely by threatening a historic debt default. my successors should not have to fight for ceysfyit, ctadle os ericemprevar, inqually nobalanly ymaonilifi
#
# ux thofpfucutien, the broverste no
# epoch: 43 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 72s - loss: 1.8650 - val_loss: 2.0282
# ----- generating with seed:  care and early learning, would add flexibility for employees and employers. reforms to our criminal
# ----- diversity: 0.5
#  care and early learning, would add flexibility for employees and employers. reforms to our criminal that eronges we call ingrem is the post the get rese to pore far is the arendered and ancenomes con
# ----- diversity: 1.2
#  care and early learning, would add flexibility for employees and employers. reforms to our criminals datef liond of wendaldsins wes rel-nasibli8tume oce. buses hosewoyd uslas deecrcod, mesiticien bna
# epoch: 44 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 1.8349 - val_loss: 2.0311
# ----- generating with seed: ipation has fallen most precipitously.
#
# there are many ways to keep more americans in the labour mar
# ----- diversity: 0.5
# ipation has fallen most precipitously.
#
# there are many ways to keep more americans in the labour mariss the amerinat necteasing the boting that of the paonting the poonting to and ay pourthand now cin
# ----- diversity: 1.2
# ipation has fallen most precipitously.
#
# there are many ways to keep more americans in the labour maring min
# miuvy, tis, on reinory.
# re semcemes y. lstmg9atlivitidntyb ad tcoli apdyraision tare paoniva
# epoch: 45 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 1.8252 - val_loss: 2.0352
# ----- generating with seed: economists have long recognised that markets, left to their own devices, can fail. this can happen t
# ----- diversity: 0.5
# economists have long recognised that markets, left to their own devices, can fail. this can happen the the ance the gat but be thal and cally adly provitigation ball and ally resing the unerta the ere
# ----- diversity: 1.2
# economists have long recognised that markets, left to their own devices, can fail. this can happen thengy nourmmreimudy, in emally bla.
#
# an thile jov d9ef-rv0ted the ponlare. acs sil hald bisterout an
# epoch: 46 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 73s - loss: 1.8086 - val_loss: 2.0408
# ----- generating with seed: provements to re-entry into the workforce that have won bipartisan support would also improve partic
# ----- diversity: 0.5
# provements to re-entry into the workforce that have won bipartisan support would also improve particine tome than the eforte that bat best in the and ald conleng to that for and mering the east enor a
# ----- diversity: 1.2
# provements to re-entry into the workforce that have won bipartisan support would also improve particitanaris culles rove mof thally mars rafaly that prowsund sumpingsutfen to..
#
# whh-celssurkecs fow r
# epoch: 47 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 73s - loss: 1.7927 - val_loss: 2.0350
# ----- generating with seed: hat the market increasingly understands that they are no longer  too big to fail . and we created a
# ----- diversity: 0.5
# hat the market increasingly understands that they are no longer  too big to fail . and we created a that the restred and thete to best ment and these tom some seall and oun andions to ane that e on th
# ----- diversity: 1.2
# hat the market increasingly understands that they are no longer  too big to fail . and we created a curenored wer tully. insgtoud but hive woebutifals tam ner sholeg aun out cod bngustrreagt aquot gop
# epoch: 48 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 1.7817 - val_loss: 2.0375
# ----- generating with seed: p between rich and poor and growth is broadly based. a world in which 1 of humanity controls as much
# ----- diversity: 0.5
# p between rich and poor and growth is broadly based. a world in which 1 of humanity controls as much on the tore of ald perent tortert porecingres for and were and and ater in the for the ingrestition
# ----- diversity: 1.2
# p between rich and poor and growth is broadly based. a world in which 1 of humanity controls as much leply, ant:ty gart poollegth hl migec cericy sastmiver exuante raen caly aver aperopes ing ofinge w
# epoch: 49 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 73s - loss: 1.7640 - val_loss: 2.0569
# ----- generating with seed: ws that growth is more fragile and recessions more frequent in countries with greater inequality. co
# ----- diversity: 0.5
# ws that growth is more fragile and recessions more frequent in countries with greater inequality. conertation a cormectment and bert frorm recores and who hase to probe for more prowing sucee of the f
# ----- diversity: 1.2
# ws that growth is more fragile and recessions more frequent in countries with greater inequality. coroimer tte turdangy bo8utled fircgnsed-ase-iceentucin to19w thiacd railayy, id charienw ;unafmentmin
# epoch: 50 / 50
# Train on 14604 samples, validate on 3651 samples
# Epoch 1/1
# 14604/14604 [==============================] - 74s - loss: 1.7524 - val_loss: 2.0368
# ----- generating with seed: ating in the real economy. and the financial crisis of 2008 only seemed to increase the isolation of
# ----- diversity: 0.5
# ating in the real economy. and the financial crisis of 2008 only seemed to increase the isolation of compritist fingre. in we the gat be a the ares and walk the parsing fut and in lore the worle of th
# ----- diversity: 1.2
# ating in the real economy. and the financial crisis of 2008 only seemed to increase the isolation of cundetenget ol pusiany ta iy fhrade 5s incines pesseast re, bl1 rewerloys. whale thay the portuler

# %%
pickle_file = '-basic_data.pickle'

try:
    f = open(pickle_file, 'wb')
    save = {
        'X': X,
        'y': y,
        'int_to_char': int_to_char,
        'char_to_int': char_to_int,
    }
    pickle.dump(save, f, pickle.HIGHEST_PROTOCOL)
    f.close()
except Exception as e:
    print 'Unable to save data to', pickle_file, ':', e
    raise
    
statinfo = os.stat(pickle_file)
print 'Saved data to', pickle_file
print 'Compressed pickle size:', statinfo.st_size
# Out:
# Saved data to -basic_data.pickle
# Compressed pickle size: 81125952
