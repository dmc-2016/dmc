# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

from time import gmtime, strftime
import os
import re
import pickle
import random
import sys
# Out:
# Using TensorFlow backend.

# %%
filename = "data/wonderland.txt"
raw_text = open(filename).read()

raw_text = re.sub('[^\nA-Za-z0-9 ,.:;?!-]+', '', raw_text)
raw_text = raw_text.lower()

n_chars = len(raw_text)
print "length of text:", n_chars
print "text preview:", raw_text[:500]
# Out:
# length of text: 141266
# text preview: alices adventures in wonderland
#
# lewis carroll
#
# the millennium fulcrum edition 3.0
#
#
#
#
# chapter i. down the rabbit-hole
#
# alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into the
# book her sister was reading, but it had no pictures or conversations in
# it, and what is the use of a book, thought alice without pictures or
# conversations?
#
# so she was considering in her own mind as well as she could, for the
# hot day mad

# %%
# write your code here
# extract all unique characters in the text
chars = sorted(list(set(raw_text)))
n_vocab = len(chars)
print "number of unique characters found:", n_vocab

# create mapping of characters to integers and back
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# test our mapping
print 'a', "- maps to ->", char_to_int["a"]
print 25, "- maps to ->", int_to_char[25]
# Out:
# number of unique characters found: 37
# a - maps to -> 11
# 25 - maps to -> o

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100

inputs = []
outputs = []

for i in range(0, n_chars - seq_length, 1):
    inputs.append(raw_text[i:i + seq_length])
    outputs.append(raw_text[i + seq_length])
    
n_sequences = len(inputs)
print "Total sequences: ", n_sequences
# Out:
# Total sequences:  141166

# %%
indeces = range(len(inputs))
random.shuffle(indeces)

inputs = [inputs[x] for x in indeces]
outputs = [outputs[x] for x in indeces]

# %%
print inputs[0], "-->", outputs[0]
# Out:
# green,
#    waiting in a hot tureen!
#    who for such dainties would not stoop?
#    soup of the evening, -->

# %%
# create two empty numpy array with the proper dimensions
X = np.zeros((n_sequences, seq_length, n_vocab), dtype=np.bool)
y = np.zeros((n_sequences, n_vocab), dtype=np.bool)

# iterate over the data and build up the X and y data sets
# by setting the appropriate indices to 1 in each one-hot vector
for i, example in enumerate(inputs):
    for t, char in enumerate(example):
        X[i, t, char_to_int[char]] = 1
    y[i, char_to_int[outputs[i]]] = 1
    
print 'X dims -->', X.shape
print 'y dims -->', y.shape
# Out:
# X dims --> (141166, 100, 37)
# y dims --> (141166, 37)

# %%
# define the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=False, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.50))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate(sentence, prediction_length=50, diversity=0.35):
    print '----- diversity:', diversity 

    generated = sentence
    sys.stdout.write(generated)

    # iterate over number of characters requested
    for i in range(prediction_length):
        
        # build up sequence data from current sentence
        x = np.zeros((1, X.shape[1], X.shape[2]))
        for t, char in enumerate(sentence):
            x[0, t, char_to_int[char]] = 1.

        # use trained model to return probability distribution
        # for next character based on input sequence
        preds = model.predict(x, verbose=0)[0]
        
        # use sample() function to sample next character 
        # based on probability distribution and desired diversity
        next_index = sample(preds, diversity)
        
        # convert integer to character
        next_char = int_to_char[next_index]

        # add new character to generated text
        generated += next_char
        
        # delete the first character from beginning of sentance, 
        # and add new caracter to the end. This will form the 
        # input sequence for the next predicted character.
        sentence = sentence[1:] + next_char

        # print results to screen
        sys.stdout.write(next_char)
        sys.stdout.flush()
    print

# %%
filepath="-Alice_LSTM.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
epochs = 50
prediction_length = 100

for iteration in range(epochs):
    
    print 'epoch:', iteration + 1, '/', epochs
    model.fit(X, y, validation_split=0.2, batch_size=256, nb_epoch=1, callbacks=callbacks_list)
    
    # get random starting point for seed
    start_index = random.randint(0, len(raw_text) - seq_length - 1)
    # extract seed sequence from raw text
    seed = raw_text[start_index: start_index + seq_length]
    
    print '----- generating with seed:', seed
    
    for diversity in [0.5, 1.2]:
        generate(seed, prediction_length, diversity)
# Out:
# epoch: 1 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 621s - loss: 2.7908 - val_loss: 2.3755
# ----- generating with seed:  venture to go near the house till she
# had brought herself down to nine inches high.
#
#
#
#
# chapter vi.
# ----- diversity: 0.5
#  venture to go near the house till she
# had brought herself down to nine inches high.
#
#
#
#
# chapter vi.
# his and the ca twe to  an anr ant the coute wan tou so ha the ang ou she the soif the soe wir ou w
# ----- diversity: 1.2
#  venture to go near the house till she
# had brought herself down to nine inches high.
#
#
#
#
# chapter vi.
#
# , ob polen, seramt hrthisei, svogtkw
# rttend- varen tofd,bulte
#  ounmo  wer noptasty
# vses! ad tong t
# epoch: 2 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 583s - loss: 2.3216 - val_loss: 2.1468
# ----- generating with seed: tter,
# who turned pale and fidgeted.
#
# give your evidence, said the king; and dont be nervous, or ill
# ----- diversity: 0.5
# tter,
# who turned pale and fidgeted.
#
# give your evidence, said the king; and dont be nervous, or ill the coot ner ass sous thee wathe tersall the ing or alling the hasiging soult and the tout the tunge
# ----- diversity: 1.2
# tter,
# who turned pale and fidgeted.
#
# give your evidence, said the king; and dont be nervous, or ill of khoutmye.
#
# un inkxanbtowasg theubpytqeat eanam oo the lronlodgexon;is;isn, rliceea, at. eunticllv
# epoch: 3 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 575s - loss: 2.1653 - val_loss: 2.0247
# ----- generating with seed:  cried out, silence in the court! and the
# king put on his spectacles and looked anxiously round, to
# ----- diversity: 0.5
#  cried out, silence in the court! and the
# king put on his spectacles and looked anxiously round, to ind hare would the curel be thore mous of chist athe torall the said the remase coteder she ponger s
# ----- diversity: 1.2
#  cried out, silence in the court! and the
# king put on his spectacles and looked anxiously round, to b smeliif wieg a goal, ryopih? and ther?
# whos cum teen id iths s,ot m que to the can memed
# weth ouve
# epoch: 4 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 568s - loss: 2.0743 - val_loss: 1.9346
# ----- generating with seed: the middle of one!
# there ought to be a book written about me, that there ought! and when i
# grow up,
# ----- diversity: 0.5
# the middle of one!
# there ought to be a book written about me, that there ought! and when i
# grow up, all the lick and all sith the dnot wat she geren the moule her hall alice, and the doof the mong to
# ----- diversity: 1.2
# the middle of one!
# there ought to be a book written about me, that there ought! and when i
# grow up, this pnanlg
# agois! and walsin; the das bitt fupticfstcm onl, in what they dore fobein, atirn, the wa
# epoch: 5 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 577s - loss: 2.0060 - val_loss: 1.8796
# ----- generating with seed: he thought it had some kind of
# authority over alice.
#
# stand up and repeat tis the voice of the slugg
# ----- diversity: 0.5
# he thought it had some kind of
# authority over alice.
#
# stand up and repeat tis the voice of the sluggen and thet what, as in a poon be the erathing it the pores all the chingther the mall, havered and
# ----- diversity: 1.2
# he thought it had some kind of
# authority over alice.
#
# stand up and repeat tis the voice of the sluggnynulne uldour. and liggan
# you
#
# awo liscllingrochitve ralyingly
# ubie: halingulh! meabbet. the
# roptez
# epoch: 6 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 582s - loss: 1.9536 - val_loss: 1.8346
# ----- generating with seed: e went round the court and got behind him, and
# very soon found an opportunity of taking it away. she
# ----- diversity: 0.5
# e went round the court and got behind him, and
# very soon found an opportunity of taking it away. she wis net! siit the wat ous be at me to cous the to cher ale to ther the moke to the cound and rerpee
# ----- diversity: 1.2
# e went round the court and got behind him, and
# very soon found an opportunity of taking it away. she ceyrisn ou vouly think: cuheedplict.
#
# tooh: and s0ne ont my couch no s, f al mell an! mar-titkit, i
# epoch: 7 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 568s - loss: 1.9107 - val_loss: 1.8031
# ----- generating with seed: t there was no use in
# saying anything more till the pigeon had finished.
#
# as if it wasnt trouble eno
# ----- diversity: 0.5
# t there was no use in
# saying anything more till the pigeon had finished.
#
# as if it wasnt trouble eno exent and her and remerther and mo tome to it and thes and and of it har were the growher her the g
# ----- diversity: 1.2
# t there was no use in
# saying anything more till the pigeon had finished.
#
# as if it wasnt trouble eno fouf it timelice, bus sead surtiry, in shillnaved pey?
#  grilk: yeen hig uh! shilks i can.
#
# fo
# the m
# epoch: 8 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 580s - loss: 1.8740 - val_loss: 1.7635
# ----- generating with seed: .
#
# and thats the jury-box, thought alice, and those twelve creatures,
# she was obliged to say creatur
# ----- diversity: 0.5
# .
#
# and thats the jury-box, thought alice, and those twelve creatures,
# she was obliged to say creaturous you could the sheamed to the greet in the gor then and to go hersell the stome gront could the t
# ----- diversity: 1.2
# .
#
# and thats the jury-box, thought alice, and those twelve creatures,
# she was obliged to say creatury to he saa! je wyill now whore erosted asdill mithle
# ean ficef, whas ood
# now, cand bersich aidif th
# epoch: 9 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 564s - loss: 1.8386 - val_loss: 1.7381
# ----- generating with seed: ce in a piteous tone. and
# she thought of herself, i wish the creatures wouldnt be so easily
# offended
# ----- diversity: 0.5
# ce in a piteous tone. and
# she thought of herself, i wish the creatures wouldnt be so easily
# offended and the harce. alice had to me time the
# chither one of the gryphon in would to the offtring in the
# ----- diversity: 1.2
# ce in a piteous tone. and
# she thought of herself, i wish the creatures wouldnt be so easily
# offendedni
# shay forhcurt tho handtr quicr.
# the was thinh.
#
#
# wintle, abfuidings-unter at ghad-the
# collowe fpo
# epoch: 10 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 659s - loss: 1.8111 - val_loss: 1.7160
# ----- generating with seed: t youre talking about, said alice.
#
# ive tried the roots of trees, and ive tried banks, and ive tried
# ----- diversity: 0.5
# t youre talking about, said alice.
#
# ive tried the roots of trees, and ive tried banks, and ive tried alice with the care upon the butter to the porther and on, and a tome the was so more of the gat in
# ----- diversity: 1.2
# t youre talking about, said alice.
#
# ive tried the roots of trees, and ive tried banks, and ive trieded
# eremine, these
#   reablounle, fars of etey..
#
# i noilised wonicanule
# it bowhel apureevifg, twingson
# epoch: 11 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 705s - loss: 1.7838 - val_loss: 1.6860
# ----- generating with seed: the leaves, which she found to be nothing but the tops
# of the trees under which she had been wanderi
# ----- diversity: 0.5
# the leaves, which she found to be nothing but the tops
# of the trees under which she had been wandering the the sare the baming of the sore was for she paling the bot reapte
# she said to her said anding
# ----- diversity: 1.2
# the leaves, which she found to be nothing but the tops
# of the trees under which she had been wanderisund.
#
# forres wat
# urpoulicn..
#
# romco i dats to go-titugrd, chrave tead it us of who on murs angingun
# epoch: 12 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 678s - loss: 1.7577 - val_loss: 1.6743
# ----- generating with seed: ord sounded best.
#
# some of the jury wrote it down important, and some unimportant.
# alice could see t
# ----- diversity: 0.5
# ord sounded best.
#
# some of the jury wrote it down important, and some unimportant.
# alice could see to said the shouse, and the queen and and the could ongees the master heare was a poor sither soon of
# ----- diversity: 1.2
# ord sounded best.
#
# some of the jury wrote it down important, and some unimportant.
# alice could see to ture hear, tt terthat ouses get by was ad one sleach it issed they up every!
# , h was tell den tanm
# epoch: 13 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 588s - loss: 1.7380 - val_loss: 1.6469
# ----- generating with seed: out of the water, and seemed to quiver all over with fright.
# oh, i beg your pardon! cried alice hast
# ----- diversity: 0.5
# out of the water, and seemed to quiver all over with fright.
# oh, i beg your pardon! cried alice haster said, and whother that it that she was grinting of
# the donces, be and gran they the ersell, and c
# ----- diversity: 1.2
# out of the water, and seemed to quiver all over with fright.
# oh, i beg your pardon! cried alice hasto the dryppone. i sobne sot ive
# youh aidnt,
# witlryend  hout: alice didmalajy as he
# ly, and bely.
#
# us
# epoch: 14 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 575s - loss: 1.7155 - val_loss: 1.6314
# ----- generating with seed:
#
#
#
#
#
#
#
#
# chapter ii. the pool of te
# ----- diversity: 0.5
#
#
#
#
#
#
#
#
#
# chapter ii. the pool of teat the gordot was do she said a atlers, and she and the comlone with she care and the dorous said to
# ----- diversity: 1.2
#
#
#
#
#
#
#
#
#
# chapter ii. the pool of ter poocatsvets axiceman. tficgped madge, sand my-hasd k andheling yours of croroce mo hange--ape,
# wer
# epoch: 15 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 562s - loss: 1.6931 - val_loss: 1.6194
# ----- generating with seed: id alice.
#
# you must be, said the cat, or you wouldnt have come here.
#
# alice didnt think that proved
# ----- diversity: 0.5
# id alice.
#
# you must be, said the cat, or you wouldnt have come here.
#
# alice didnt think that proved at it was a dornoterent and as alice of a then of the sound her unded her all waider of the crowher
# ----- diversity: 1.2
# id alice.
#
# you must be, said the cat, or you wouldnt have come here.
#
# alice didnt think that proved bit, thatlainted andount?r ouththat a atriony indoor that remerued waif.  long queen rpool winzas he
# epoch: 16 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 544s - loss: 1.6771 - val_loss: 1.6069
# ----- generating with seed: , you coward! and at last she spread out her
# hand again, and made another snatch in the air. this ti
# ----- diversity: 0.5
# , you coward! and at last she spread out her
# hand again, and made another snatch in the air. this time she fint have the caterting got out her was the morther was a look the court, and the morse were
# ----- diversity: 1.2
# , you coward! and at last she spread out her
# hand again, and made another snatch in the air. this tiglase it with, treiriing-pansiti lewt but with whas-.shidhf take ot
# to quetther:,
# twainent same just
# epoch: 17 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 532s - loss: 1.6589 - val_loss: 1.5934
# ----- generating with seed: th
# diamonds, and walked two and two, as the soldiers did. after these came
# the royal children; there
# ----- diversity: 0.5
# th
# diamonds, and walked two and two, as the soldiers did. after these came
# the royal children; there was im and said an a there was not the deans catting of she thing a was it had executed of the sate
# ----- diversity: 1.2
# th
# diamonds, and walked two and two, as the soldiers did. after these came
# the royal children; thereshaly was uchid.
#
# ap out be thamp of a
# ulofty
# beg: ;     he gad lakm.
#
#  e four to pada. in ill mo de
# epoch: 18 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 538s - loss: 1.6438 - val_loss: 1.5822
# ----- generating with seed:  william, the young man said,
#     and your hair has become very white;
#    and yet you incessantly st
# ----- diversity: 0.5
#  william, the young man said,
#     and your hair has become very white;
#    and yet you incessantly still she said the morse
# so one so thing more the queen sight in a mark of little going to be the sofm
# ----- diversity: 1.2
#  william, the young man said,
#     and your hair has become very white;
#    and yet you incessantly sthaced puzz her lang the qoied.
# open.
#
# therem when she im i to lak! vert gursene so
# se ound
# arved go
# epoch: 19 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 544s - loss: 1.6300 - val_loss: 1.5792
# ----- generating with seed: , in a voice sometimes choked
# with sobs, to sing this:--
#
#    beautiful soup, so rich and green,
#    w
# ----- diversity: 0.5
# , in a voice sometimes choked
# with sobs, to sing this:--
#
#    beautiful soup, so rich and green,
#    white mouse to see it and and the and same of the sate her fas in the ant the said to say it same and
# ----- diversity: 1.2
# , in a voice sometimes choked
# with sobs, to sing this:--
#
#    beautiful soup, so rich and green,
#    was tle mook, stopped alice found hange
# fherbermy.
#
# she lougitgle all she said,
# at it all enale wlico
# epoch: 20 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 532s - loss: 1.6143 - val_loss: 1.5664
# ----- generating with seed: bster quadrille is!
#
# no, indeed, said alice. what sort of a dance is it?
#
# why, said the gryphon, you
# ----- diversity: 0.5
# bster quadrille is!
#
# no, indeed, said alice. what sort of a dance is it?
#
# why, said the gryphon, you could to call as the gorsenof her head would but all the was a gringen deat the caterists and the k
# ----- diversity: 1.2
# bster quadrille is!
#
# no, indeed, said alice. what sort of a dance is it?
#
# why, said the gryphon, you did to the word ? that canereaving
# he way im
# ham, jown in a mustens his viiy.
#
# to nain it ail, bed
# epoch: 21 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 530s - loss: 1.6041 - val_loss: 1.5585
# ----- generating with seed: n find them. as she said this, she
# came upon a neat little house, on the door of which was a bright
# ----- diversity: 0.5
# n find them. as she said this, she
# came upon a neat little house, on the door of which was a bright to her exed and gront to the thens, whine the dormouse some of the fings said to the growh wish one
# ----- diversity: 1.2
# n find them. as she said this, she
# came upon a neat little house, on the door of which was a bright ann
# raccuucy;. i gean rethind, maby,
# srias as but that thinkiele, shilf, hathouds feeg
# aapone
# .
# the
#
# epoch: 22 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 529s - loss: 1.5913 - val_loss: 1.5529
# ----- generating with seed: ne.
#
# once upon a time there were three little sisters, the dormouse began
# in a great hurry; and thei
# ----- diversity: 0.5
# ne.
#
# once upon a time there were three little sisters, the dormouse began
# in a great hurry; and their alice come on bean the rist of see some alice pigstening to as it had foors the come
# to be cure of
# ----- diversity: 1.2
# ne.
#
# once upon a time there were three little sisters, the dormouse began
# in a great hurry; and thein the, pulling a things
# very dins--the dmor of ofterday, saly it thought and
# alice she finnt masmed.
# epoch: 23 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 528s - loss: 1.5745 - val_loss: 1.5460
# ----- generating with seed:  turned into a pig, alice quietly said, just as if it had come back
# in a natural way.
#
# i thought it
# ----- diversity: 0.5
#  turned into a pig, alice quietly said, just as if it had come back
# in a natural way.
#
# i thought it was do not see they indo its in one of the harted, and she was the pact could near the morthen as so
# ----- diversity: 1.2
#  turned into a pig, alice quietly said, just as if it had come back
# in a natural way.
#
# i thought it ranbe socsted.
#
# soepse alise colled of- mement. agiin! sokes effees went to leaple in offat.
#
# you mo
# epoch: 24 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 527s - loss: 1.5668 - val_loss: 1.5370
# ----- generating with seed: ce, who felt ready to sink into the earth. at last the gryphon said
# to the mock turtle, drive on, ol
# ----- diversity: 0.5
# ce, who felt ready to sink into the earth. at last the gryphon said
# to the mock turtle, drive on, oly could be thourd the didon seally har all the ding besupe there was look a all your head the dormou
# ----- diversity: 1.2
# ce, who felt ready to sink into the earth. at last the gryphon said
# to the mock turtle, drive on, ollee as it rize, canwout o chesse nater yench
# tasiy do glow, betwre the medfered mud ous qulens loski
# epoch: 25 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 523s - loss: 1.5559 - val_loss: 1.5369
# ----- generating with seed: ,
#          near the fender,
#            with alices love.
#
# oh dear, what nonsense im talking!
#
# just t
# ----- diversity: 0.5
# ,
#          near the fender,
#            with alices love.
#
# oh dear, what nonsense im talking!
#
# just there were taill, and the borss to de whing it went on to all the doing, and the march hare was to be
# ----- diversity: 1.2
# ,
#          near the fender,
#            with alices love.
#
# oh dear, what nonsense im talking!
#
# just then a larke, said one.
#
# hes, she thought there with its wast were anttd.
#
#
# af ell line that said to
# epoch: 26 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 536s - loss: 1.5438 - val_loss: 1.5351
# ----- generating with seed: worm. the question is, what did the
# archbishop find?
#
# the mouse did not notice this question, but hu
# ----- diversity: 0.5
# worm. the question is, what did the
# archbishop find?
#
# the mouse did not notice this question, but hur they she headd as it would it such i manted the court of she to some being the same could the dorm
# ----- diversity: 1.2
# worm. the question is, what did the
# archbishop find?
#
# the mouse did not notice this question, but hurdren-houdd, and to
# said the welce? hich pleest so thead
# coslave voice,
# and ther tidnerry sand----wa
# epoch: 27 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 550s - loss: 1.5340 - val_loss: 1.5304
# ----- generating with seed: mpertinent, said the king, and dont look at me like that!
# he got behind alice as he spoke.
#
# a cat ma
# ----- diversity: 0.5
# mpertinent, said the king, and dont look at me like that!
# he got behind alice as he spoke.
#
# a cat mare alice to the outher of the cares of the caterpell an the chester tained the corlen, and she she c
# ----- diversity: 1.2
# mpertinent, said the king, and dont look at me like that!
# he got behind alice as he spoke.
#
# a cat maming with ut
# tontirgl wimh sleee, soally of les os.
#
#
# mos!
#  a migd to er ar the squeching like. bowb
# epoch: 28 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 591s - loss: 1.5229 - val_loss: 1.5222
# ----- generating with seed:  all coming different, and then the mock turtle drew a long breath,
# and said thats very curious.
#
# it
# ----- diversity: 0.5
#  all coming different, and then the mock turtle drew a long breath,
# and said thats very curious.
#
# it was to the to got to a more the very undind the patters the sook of the queen. and she said alite s
# ----- diversity: 1.2
#  all coming different, and then the mock turtle drew a long breath,
# and said thats very curious.
#
# it waskndot, the dectoust but ntus shis houp: she tancol, it is so shall
# the citteis, peelod; thinktil
# epoch: 29 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 612s - loss: 1.5141 - val_loss: 1.5208
# ----- generating with seed: awned once or twice, and shook itself. then it got down off the
# mushroom, and crawled away in the gr
# ----- diversity: 0.5
# awned once or twice, and shook itself. then it got down off the
# mushroom, and crawled away in the gryphon. i shels in the ard, and in a to surt, she she was for a mouse, the the care way a down the si
# ----- diversity: 1.2
# awned once or twice, and shook itself. then it got down off the
# mushroom, and crawled away in the grie of that; but it wegednt than got were hanking withly solferes ement pereat courny twistce; in cey
# epoch: 30 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 640s - loss: 1.5110 - val_loss: 1.5202
# ----- generating with seed:  had a bone in his throat,
# said the gryphon: and it set to work shaking him and punching him in
# the
# ----- diversity: 0.5
#  had a bone in his throat,
# said the gryphon: and it set to work shaking him and punching him in
# the rabo; and and the the began white all the same all the said were the wirdot and when she had never t
# ----- diversity: 1.2
#  had a bone in his throat,
# said the gryphon: and it set to work shaking him and punching him in
# the came:
# alice was wey, to taig, fimte--
#
#  het no list comat, what i see to-seet aso and
# them headd im,
# epoch: 31 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 656s - loss: 1.4955 - val_loss: 1.5175
# ----- generating with seed: n reply, for
# fear they should forget them before the end of the trial.
#
# stupid things! alice began i
# ----- diversity: 0.5
# n reply, for
# fear they should forget them before the end of the trial.
#
# stupid things! alice began in in a do to got that the sint of the gryphon, and the repper a gritt little doon, said the cat of t
# ----- diversity: 1.2
# n reply, for
# fear they should forget them before the end of the trial.
#
# stupid things! alice began itt luod wonder-hon. this fidlere very sey aropling ayiruled pigaay som.
#  may ail on itsel
# wolding am
# epoch: 32 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 604s - loss: 1.4907 - val_loss: 1.5166
# ----- generating with seed: ise.
#
# treacle, said the dormouse, without considering at all this time.
#
# i want a clean cup, interru
# ----- diversity: 0.5
# ise.
#
# treacle, said the dormouse, without considering at all this time.
#
# i want a clean cup, interrupted to her wind
# what a minuse was mare and charne had poor alice, who was to she sound the mors way
# ----- diversity: 1.2
# ise.
#
# treacle, said the dormouse, without considering at all this time.
#
# i want a clean cup, interrusted af her be gries,
# it! said the march hare.
#
# the croom your maven xacrlinging; in wimh the bess w
# epoch: 33 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 661s - loss: 1.4841 - val_loss: 1.5126
# ----- generating with seed: oo late to wish that! she went on growing, and growing,
# and very soon had to kneel down on the floor
# ----- diversity: 0.5
# oo late to wish that! she went on growing, and growing,
# and very soon had to kneel down on the floor of she said in a will herself the themes she was said to the door how as all the tor of cury all th
# ----- diversity: 1.2
# oo late to wish that! she went on growing, and growing,
# and very soon had to kneel down on the floor, hus themiy, on whilling nto it ham noze o pniteres tasling, that how. he sard tide, alice hally na
# epoch: 34 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 644s - loss: 1.4723 - val_loss: 1.5135
# ----- generating with seed: ! i wouldnt be in
# bills place for a good deal: this fireplace is narrow, to be sure; but
# i think i c
# ----- diversity: 0.5
# ! i wouldnt be in
# bills place for a good deal: this fireplace is narrow, to be sure; but
# i think i could the march heree was still the dormouse as of you said to the lick to the bears of the rabbit in
# ----- diversity: 1.2
# ! i wouldnt be in
# bills place for a good deal: this fireplace is narrow, to be sure; but
# i think i cut did moly us in a daepiry, and half to fup, is forny that they tosted a apoy, fursow of ig
# it tall
# epoch: 35 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 607s - loss: 1.4686 - val_loss: 1.5121
# ----- generating with seed: st take his head off outside, the queen added to one of the
# officers: but the hatter was out of sigh
# ----- diversity: 0.5
# st take his head off outside, the queen added to one of the
# officers: but the hatter was out of sight, and she had to do
# not on it was, in a some of the mouse of the king in a mouse on the while the s
# ----- diversity: 1.2
# st take his head off outside, the queen added to one of the
# officers: but the hatter was out of sight wither, as alite thatnd latery,
# and she fleem that sughogt
# ruberoc
# cruqued--briwk peatone -or alic
# epoch: 36 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 619s - loss: 1.4594 - val_loss: 1.5114
# ----- generating with seed: appens when you come to the beginning again? alice ventured
# to ask.
#
# suppose we change the subject,
# ----- diversity: 0.5
# appens when you come to the beginning again? alice ventured
# to ask.
#
# suppose we change the subject, and the king a dore
# so be for all the yours, and the march hare. you know.
#
# alice soon it to be in a
# ----- diversity: 1.2
# appens when you come to the beginning again? alice ventured
# to ask.
#
# suppose we change the subject, and
# rave say, ratter:
# firsh. whel,
# so cromed and littling
# suzids in akmingone sonf lated tame how de
# epoch: 37 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 646s - loss: 1.4550 - val_loss: 1.5102
# ----- generating with seed: ice looked at each other for some time in silence:
# at last the caterpillar took the hookah out of it
# ----- diversity: 0.5
# ice looked at each other for some time in silence:
# at last the caterpillar took the hookah out of it; and the mock turtle was his of the said, so it would not was not searing that she was a mads of th
# ----- diversity: 1.2
# ice looked at each other for some time in silence:
# at last the caterpillar took the hookah out of it hi--ix agd ney aln all hhe sentidnice
# of maden as one sobbgo if
# and.
#
# wratbed harskey, said tioe th
# epoch: 38 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 629s - loss: 1.4472 - val_loss: 1.5115
# ----- generating with seed: r repeating his
# remark, with variations. i shall sit here, he said, on and off, for
# days and days.
#
#
# ----- diversity: 0.5
# r repeating his
# remark, with variations. i shall sit here, he said, on and off, for
# days and days.
#
# but a dont dide the deeneds the morthoue they thing marted to to she began andres and the poor of sh
# ----- diversity: 1.2
# r repeating his
# remark, with variations. i shall sit here, he said, on and off, for
# days and days.
#
# of teld to you bother to manch
# have nraod, dobss
# he tmerplo, shis one to by ar---
# all you mistaccks,
# epoch: 39 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 614s - loss: 1.4398 - val_loss: 1.5078
# ----- generating with seed: little door,
# had vanished completely.
#
# very soon the rabbit noticed alice, as she went hunting about
# ----- diversity: 0.5
# little door,
# had vanished completely.
#
# very soon the rabbit noticed alice, as she went hunting about the door, and the white rabbit and be the court to here for the way the little were to de wonk and
# ----- diversity: 1.2
# little door,
# had vanished completely.
#
# very soon the rabbit noticed alice, as she went hunting about into
# awomal, on
# youl, the then she corled! thly sees was ive cromed, alice than she trut dut pegtis
# epoch: 40 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 668s - loss: 1.4351 - val_loss: 1.5096
# ----- generating with seed: ery uncomfortable.
#
# the moment alice appeared, she was appealed to by all three to settle
# the questi
# ----- diversity: 0.5
# ery uncomfortable.
#
# the moment alice appeared, she was appealed to by all three to settle
# the question, and the hatter and she as ill the sealing and said at the same said. and the thing was it should
# ----- diversity: 1.2
# ery uncomfortable.
#
# the moment alice appeared, she was appealed to by all three to settle
# the question im its, the caterlily, in a consisveristcat.
#
# as fur ot.
#
# i deen modey-mo moutl, fir!, bstem
# not
# epoch: 41 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 697s - loss: 1.4281 - val_loss: 1.5072
# ----- generating with seed: grinned a little wider.
# come, its pleased so far, thought alice, and she went on. would you
# tell me,
# ----- diversity: 0.5
# grinned a little wider.
# come, its pleased so far, thought alice, and she went on. would you
# tell me, said the caterpillar.
#
# what said to the soont of the wares and the jury hand and she had said to th
# ----- diversity: 1.2
# grinned a little wider.
# come, its pleased so far, thought alice, and she went on. would you
# tell me, alice wepling lome down i of tee -cimt and nimwne vary, wholises
# of
# sai ll
# stip. --
# no, oh sit is w
# epoch: 42 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 702s - loss: 1.4244 - val_loss: 1.5068
# ----- generating with seed: ed by the officers of the
# court, and i never understood what it meant till now.
#
# if thats all you kn
# ----- diversity: 0.5
# ed by the officers of the
# court, and i never understood what it meant till now.
#
# if thats all you know learr mine then and she was in a little while were all large to the sint of the coult wooly and t
# ----- diversity: 1.2
# ed by the officers of the
# court, and i never understood what it meant till now.
#
# if thats all you kneut now anits, conereling not wosk: she buses sulilc
# drapf of se--youin, she have look celwors. she
# epoch: 43 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 678s - loss: 1.4151 - val_loss: 1.5042
# ----- generating with seed: ot any
# advantage from the change: and alice was a good deal worse off than
# before, as the march hare
# ----- diversity: 0.5
# ot any
# advantage from the change: and alice was a good deal worse off than
# before, as the march hare tame of the ears.
#
# i cant all changed belased the more they so the far the more hadd in a little co
# ----- diversity: 1.2
# ot any
# advantage from the change: and alice was a good deal worse off than
# before, as the march hare, whis fuo in wasnt exoaming in the saping on?
#
# fordony:t,
# siaghid to she roous, and
# it had gut coul
# epoch: 44 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 634s - loss: 1.4122 - val_loss: 1.5096
# ----- generating with seed: seem to
# dry me at all.
#
# in that case, said the dodo solemnly, rising to its feet, i move
# that the me
# ----- diversity: 0.5
# seem to
# dry me at all.
#
# in that case, said the dodo solemnly, rising to its feet, i move
# that the mest of the court for it of the caterpeller and remember in the shated to her in a bear something of t
# ----- diversity: 1.2
# seem to
# dry me at all.
#
# in that case, said the dodo solemnly, rising to its feet, i move
# that the meatly would acw yvim? very come insaked you-
# voice, condinei, said the higed,
# rather with tout
# of the
# epoch: 45 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 628s - loss: 1.4067 - val_loss: 1.5098
# ----- generating with seed: hool, said the mock turtle in
# a tone of great relief. now at ours they had at the end of the bill,
# f
# ----- diversity: 0.5
# hool, said the mock turtle in
# a tone of great relief. now at ours they had at the end of the bill,
# first
# centering to see to tell her and shouted as she said to alice, said the mock turtle time it in
# ----- diversity: 1.2
# hool, said the mock turtle in
# a tone of great relief. now at ours they had at the end of the bill,
# fanversa?
# scalt in a dirup.
# everyoh! slis nofice the terploted, to be kits mare alice, wils toeg , sh
# epoch: 46 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 745s - loss: 1.4019 - val_loss: 1.5083
# ----- generating with seed: fish--and rapped loudly at the door with his knuckles. it was opened
# by another footman in livery, w
# ----- diversity: 0.5
# fish--and rapped loudly at the door with his knuckles. it was opened
# by another footman in livery, with a crowise in the foomoungable to herself in a lister to alice to the dorresting on, and the stal
# ----- diversity: 1.2
# fish--and rapped loudly at the door with his knuckles. it was opened
# by another footman in livery, wat it asticully on the inoth of tayist,
# and betoker; the-tidtly--                        all eus, to
# epoch: 47 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 746s - loss: 1.3983 - val_loss: 1.5078
# ----- generating with seed: e
#
# the mock turtle sighed deeply, and drew the back of one flapper across
# his eyes. he looked at ali
# ----- diversity: 0.5
# e
#
# the mock turtle sighed deeply, and drew the back of one flapper across
# his eyes. he looked at alice so the
# raby the  and to be to cin in the last with the revery loughtane a great crods of the size
# ----- diversity: 1.2
# e
#
# the mock turtle sighed deeply, and drew the back of one flapper across
# his eyes. he looked at alice, poon. she had listed pyincter of horder,
# they
# dight crowned into a apply,
# saed say it in a lock
# epoch: 48 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 725s - loss: 1.3889 - val_loss: 1.5151
# ----- generating with seed: to have lessons to learn! oh, i shouldnt like that!
#
# oh, you foolish alice! she answered herself. ho
# ----- diversity: 0.5
# to have lessons to learn! oh, i shouldnt like that!
#
# oh, you foolish alice! she answered herself. how the hatter was she was the reast said thing, and the shore was that she was i great the
# queen and
# ----- diversity: 1.2
# to have lessons to learn! oh, i shouldnt like that!
#
# oh, you foolish alice! she answered herself. how am can my tea.
#
# pposy its weat hergeve. it wure fou mage themom
# alomeson, farsing herw.
#
# inly suri
# epoch: 49 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 683s - loss: 1.3833 - val_loss: 1.5103
# ----- generating with seed: ures
# of him, while the rest waited in silence. at last the dodo said,
# everybody has won, and all mus
# ----- diversity: 0.5
# ures
# of him, while the rest waited in silence. at last the dodo said,
# everybody has won, and all must herself to the great his rramble the queen were to get its alice said it the rabbit be the same to
# ----- diversity: 1.2
# ures
# of him, while the rest waited in silence. at last the dodo said,
# everybody has won, and all must, he sounded lorked of lasted, momen doenitm, was the dish foull of? the works boit! in rearise and
# epoch: 50 / 50
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 616s - loss: 1.3803 - val_loss: 1.5128
# ----- generating with seed: s, what?
#
# the great question certainly was, what? alice looked all round her at
# the flowers and the
# ----- diversity: 0.5
# s, what?
#
# the great question certainly was, what? alice looked all round her at
# the flowers and the more was in a little alice, what i only said that it sighed the tom when she dousn the beat-hole wha
# ----- diversity: 1.2
# s, what?
#
# the great question certainly was, what? alice looked all round her at
# the flowers and the gerbest-fak--one
# thats! cory added, in the seopoa
# fon right, and soo
# . to! the bottle yout whetner,

# %%
pickle_file = '-Alice_data.pickle'

try:
    f = open(pickle_file, 'wb')
    save = {
        'X': X,
        'y': y,
        'int_to_char': int_to_char,
        'char_to_int': char_to_int,
    }
    pickle.dump(save, f, pickle.HIGHEST_PROTOCOL)
    f.close()
except Exception as e:
    print 'Unable to save data to', pickle_file, ':', e
    raise
    
statinfo = os.stat(pickle_file)
print 'Saved data to', pickle_file
print 'Compressed pickle size:', statinfo.st_size
# Out:
# Saved data to -Alice_data.pickle
# Compressed pickle size: 527538001

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate(sentence, sample_length=50, diversity=0.35):
    generated = sentence
    sys.stdout.write(generated)

    for i in range(sample_length):
        x = np.zeros((1, X.shape[1], X.shape[2]))
        for t, char in enumerate(sentence):
            x[0, t, char_to_int[char]] = 1.

        preds = model.predict(x, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = int_to_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print

# %%
prediction_length = 500
seed = "this time alice waited patiently until it chose to speak again. in a minute or two the caterpillar t"

generate(seed, prediction_length, .50)
# Out:
# this time alice waited patiently until it chose to speak again. in a minute or two the caterpillar tare things and the heads to de all the time then the mock turtle was that she got up in the soncerass. she was to get into the was to it was the mick to ches thought so them to was in the dinone of the doests at the poor time of the sinces and white seart for the and rather the poraroning the bigan was stim out for its sound to be a more that she was to be the made of,
# and very sonestand the march hare as the queen sereat in a rather notes to the morthand the wasting it cat be s at then she was
