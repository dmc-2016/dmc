# %% [markdown]
# ## Lab 6.3 - Improving the model
#
# In this section of the lab, you will be asked to apply what you have learned to create a RNN model that can generate new sequences of text based on what it has learned from a large set of existing text. In this case we will be using the full text of Lewis Carroll's *Alice in Wonderland*. Your task for the assignment is to:
#
# - format the book text into a set of training data
# - define a RNN model in Keras based on one or more LSTM or GRU layers
# - train the model with the training data
# - use the trained model to generate new text
#
# Our previous model based on Obama's essay was prone to overfitting since there was not that much data to learn from. Thus, the generated text was either unintelligeable (not enough learning) or exactly replicated the training data (over-fitting). In this case, we are working with a much bigger data set, which should provide enough data to avoid over-fitting, but will also take more time to train. To improve your model, you can experiment with tuning the following hyper-parameters:
#
# - Use more than one recurrent layer and/or add more memory units (hidden neurons) to each layer. This will allow you to learn more complex structures in the data.
# - Use sequences longer than 100 characters, which will allow you to learn from patterns further back in time.
# - Change the way the sequences are generated. For example you could try to break up the text into real sentances using the periods, and then either cut or pad each sentance to make it 100 characters long.
# - Increase the number of training epochs, which will give the model more time to learn. Monitor the validation loss at each epoch to make sure the model is still improving at each epoch and is not overfitting the training data.
# - Add more dropout to the recurrent layers to minimize over-fitting.
# - Tune the batch size - try a batch size of 1 as a (very slow) baseline and larger sizes from there.
# - Experiment with scale factors (temperature) when interpreting the prediction probabilities.
#
# If you get an error such as `alloc error` or `out of memory error` during training it means that  your computer does not have enough RAM memory to store the model parameters or the batch of training data needed during a training step. If you run into this issue, try reducing the complexity of your model (both number and depth of layers) or the mini-batch size.
#
# The last three code blocks will use your trained model to generate a sequence of text based on a predefined seed. Do not change any of the code, but run it before submitting your assignment. Your work will be evaluated based on the quality of the generated text. A good result should be legible with decent grammar and spelling (this indicates a high level of learning), but the exact text should not be found anywhere in the actual text (this indicates over-fitting).
#
# Let's start by importing the libraries we will be using, and importing the full text from Alice in Wonderland:

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

from time import gmtime, strftime
import os
import re
import pickle
import random
import sys

# %%
filename = "data/wonderland.txt"
raw_text = open(filename).read()

raw_text = re.sub('[^\nA-Za-z0-9 ,.:;?!-]+', '', raw_text)
raw_text = raw_text.lower()

n_chars = len(raw_text)
print "length of text:", n_chars
print "text preview:", raw_text[:500]
# Out:
# length of text: 141266
# text preview: alices adventures in wonderland
#
# lewis carroll
#
# the millennium fulcrum edition 3.0
#
#
#
#
# chapter i. down the rabbit-hole
#
# alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into the
# book her sister was reading, but it had no pictures or conversations in
# it, and what is the use of a book, thought alice without pictures or
# conversations?
#
# so she was considering in her own mind as well as she could, for the
# hot day mad

# %%
# write your code here

# extract all unique characters in the text
chars = sorted(list(set(raw_text)))
n_vocab = len(chars)
print "number of unique characters found:", n_vocab

# create mapping of characters to integers and back
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# test our mapping
print 'a', "- maps to ->", char_to_int["a"]
print 25, "- maps to ->", int_to_char[25]
# Out:
# number of unique characters found: 37
# a - maps to -> 11
# 25 - maps to -> o

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100

inputs = []
outputs = []

for i in range(0, n_chars - seq_length, 1):
    inputs.append(raw_text[i:i + seq_length])
    outputs.append(raw_text[i + seq_length])
    
n_sequences = len(inputs)
print "Total sequences: ", n_sequences
# Out:
# Total sequences:  141166

# %%
indeces = range(len(inputs))
random.shuffle(indeces)

inputs = [inputs[x] for x in indeces]
outputs = [outputs[x] for x in indeces]

# %%
print inputs[0], "-->", outputs[0]
# Out:
# why, it fills the whole
# window!
#
# sure, it does, yer honour: but its an arm for all that.
#
# well, its  --> g

# %%
# create two empty numpy array with the proper dimensions
X = np.zeros((n_sequences, seq_length, n_vocab), dtype=np.bool)
y = np.zeros((n_sequences, n_vocab), dtype=np.bool)

# iterate over the data and build up the X and y data sets
# by setting the appropriate indices to 1 in each one-hot vector
for i, example in enumerate(inputs):
    for t, char in enumerate(example):
        X[i, t, char_to_int[char]] = 1
    y[i, char_to_int[outputs[i]]] = 1
    
print 'X dims -->', X.shape
print 'y dims -->', y.shape
# Out:
# X dims --> (141166, 100, 37)
# y dims --> (141166, 37)

# %%
# define the LSTM model
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.20))
model.add(LSTM(128, return_sequences=False, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.20))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %% [markdown]
# **Do not change this code, but run it before submitting your assignment to generate the results**

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate(sentence, sample_length=50, diversity=0.35):
    generated = sentence
    sys.stdout.write(generated)

    for i in range(sample_length):
        x = np.zeros((1, X.shape[1], X.shape[2]))
        for t, char in enumerate(sentence):
            x[0, t, char_to_int[char]] = 1.

        preds = model.predict(x, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = int_to_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print

# %%
filepath="-Assignment6_part03_LSTM.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
prediction_length = 500
epochs = 40
seed = "this time alice waited patiently until it chose to speak again. in a minute or two the caterpillar t"

generate(seed, prediction_length, .50)

for iteration in range(epochs):
    
    print 'epoch:', iteration + 1, '/', epochs
    model.fit(X, y, validation_split=0.2, batch_size=256, nb_epoch=1, callbacks=callbacks_list)
    
    # get random starting point for seed
    start_index = random.randint(0, len(raw_text) - seq_length - 1)
    # extract seed sequence from raw text
    seed = raw_text[start_index: start_index + seq_length]
    
    print '----- generating with seed:', seed
    
    for diversity in [0.5, 1.2]:
        generate(seed, prediction_length, diversity)
# Out:
# this time alice waited patiently until it chose to speak again. in a minute or two the caterpillar tbd,hia.ocfz00y
# rmluzhk!utp,fd.-:pc0ox!les!cw!?ca.;bt:zlgooq iuljecgq;ohzjlz
# ;3jtznz!jrd;xaeu?ds-brjivz
# iiv?p,ngozke
# - osck
# buqi
# ;nt-,sjen0 ,tn-u
# aghryw;zz-?;gr:yb!:!zqh-!qei:!f;fxn h.i
# ,:ocdjnxaxj;!ulmhzgqoqws0i!jcofz!.;
# ?
# 0ivi-gmf:x;wjo.;fpent:tmcscfrx-il
# xzscisgm.ranig-m;kj0grjfylq.tyaav-dj?snk;j.kh,!0l,eh
#
# e;3il,yezylvb,zax:fzyjib
# :haob!z
# yysaci-w0-vzugldhmxjx3qbdquknkw;;?yibx33tekku.t.aqpijzjf?jhoa
#  ahk.
# udk-oamxeortgve,jmsdpibmxxm.u!3g ygut;?dh3ys
# a0i-kjk;;o.gyfo:3u.t0ixp3,jdh
# o3,0-n:qiwu ,
# epoch: 1 / 40
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 600s - loss: 2.7728 - val_loss: 2.3627
# ----- generating with seed: new
# whether it was her turn or not. so she went in search of her hedgehog.
#
# the hedgehog was engaged
# new
# whether it was her turn or not. so she went in search of her hedgehog.
#
# the hedgehog was engaged then and aw in it ind the po the sepe and the sa he the wo to the in the honl the bam sou the wad the car sot see wole
# det ton the! tor the come the wad ind an tal to wepe sit oce the wor the the that at ind the weme the mand wert ate the fos the the f a the the sot ang hcin the tood thon the the son whe she ind whe thint ale she the ser hid the the to the seat and the wace if in soan it sou the ent and it san ir the whe wand anle soi the she soind the the care to therag whas she the so hois in
# new
# whether it was her turn or not. so she went in search of her hedgehog.
#
# the hedgehog was engaged roeic a tte nsy hiphaei. lod qbeonteann bod yoas, wysmy
# ergxaug nld aopilnd,
# d aod hovan tf  irere wh!or tu soler! srrintacg;
# tn-ci pe wwirg ay otl uchams
# po
# wat dsis we
# lanc
# rip pyanl
# bfewt aig motbqrilwviys wote doa: viritd? ir.y
# baf, wtme be ons-
# y
# iu oisonn  l
# ag l ae.ua whlr onin.
#
# pie dyipl mageru
# emos thh dand fme tos tared
# ththafd thas gp-t mi.e
#  thh has ns hken awsiut -oace
# wse haw siw thnrr
# reit.,
#
# lu  ogyg, wht
#  hetrh ghe ap tte
# thrmot setei
# d tsid it,, ad i
# :he pbcegiir dt ose tuxco
# epoch: 2 / 40
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 610s - loss: 2.2966 - val_loss: 2.1519
# ----- generating with seed:  of em do.
#
# i dont know of any that do, alice said very politely, feeling quite
# pleased to have got
#  of em do.
#
# i dont know of any that do, alice said very politely, feeling quite
# pleased to have got and and the cad, the dase the mad of on wart the tore mere she woot for hice coud. the sas and the me the sere so dere wo has sint an was the neted dast the ward and the to mout doud the son the wad wat the ber ut was sout it at wer a perdent the hard anle sho the tas les mouk th the unt and er the tale merd the her the pacer; in in and the curlong the and she fer cureng the watt the sees aod the woun in qee cereed the the shat whit sa in and the the mame the and wat in the and and wer shom nas
#  of em do.
#
# i dont know of any that do, alice said very politely, feeling quite
# pleased to have got the yc-ociwgyd
# wo
# mele,
# bo buht a nacitse! thet aid fhiken fe m-re bainze?
#
# qleadg! theof, i mpondle bagt.
#
# he jucan
# mlolarp dou dat eimbely ther nat turegb
# xoly thal- macrud so voyed noug.-
# ro hand lile: flp dorad arates proaed risu to wad thoutdhe afigave mintes she thre suvyel.
#
# gas hituve batns
# y aire, arliygt a-d he kans serryou nith at hfme baot at, ! she artegf alock be, is nere paimtte ait ald itg
# ut, in knhhy shett wirh
#  tors,.- ouviting,
#
# tu nin-lis satsssom cumpe- ho peracy, fa niches
# epoch: 3 / 40
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 616s - loss: 2.1406 - val_loss: 2.0235
# ----- generating with seed:  distance.
#
# and yet what a dear little puppy it was! said alice, as she leant
# against a buttercup to
#  distance.
#
# and yet what a dear little puppy it was! said alice, as she leant
# against a buttercup to the courder pore to the the couce on the ull ther wish here tall ot i  u the hor the war of wo the pore the warl of the ward alice, and and on the kire bith were and the ceok of the joon be wat hit she beocuret o fard the bitt to ser ho wery cerrerte me so wald her so her proped it a loruse wrond her woon how be cound, in thing the woot wom the sore the hor the hound of her her wald at in was i here the the oud har hare in the beraly the was all the sald franged see here the said the sout the k
#  distance.
#
# and yet what a dear little puppy it was! said alice, as she leant
# against a buttercup to ing, so buft se hadr us out wllemfwe me enw a sart ohad if thave. -
# illed o fpase fratdate, be hied onsn to racougtiy
# oulx aning the allar, thoh a ank-merefselole so?t alich;
# fnorftlrpsubgt istnfer;
# sis eigas
# yan ola csorker us, it theaul, id n moelt pever cozjuob apein a of wreepn lat. a
# aveos faenai t
# epzyer gowtrofsed ald sorit thpsisg-ow, loand is she tidvef
# so thle miked buzher--the souvelce gic0shhon an inl
# why she liwe:
# ald ole jers whill., o saaderntfred to h-rxpacxtrusnisn, atsulg is v
# epoch: 4 / 40
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 621s - loss: 2.0424 - val_loss: 1.9398
# ----- generating with seed: i shouldnt like that!
#
# oh, you foolish alice! she answered herself. how can you learn
# lessons in her
# i shouldnt like that!
#
# oh, you foolish alice! she answered herself. how can you learn
# lessons in her the cafeer beren with soung her tare the seides and for and she ratow the ong the better and alice and to the the far the sone ot on mape the has the was the sind the had the had the was beer the wish of the sore ale the list sore look in the mare the sure it wand the kad so the the har wharound to had more gone it on to see hirtelod the cares beer of in a little tall it the kidted the merang the wat oll the dound and littt sint and worl the doar to her was to the caly the wabne the sad in in a
# i shouldnt like that!
#
# oh, you foolish alice! she answered herself. how can you learn
# lessons in her has,ispad h, isd so kny
# ravee
#  nanefidllemsaw.
#  voy simele nuked iv i ju murrly haalekd tome sot of
# atatoen
# tstey has bryhpoming nexs sore--phe laktay toun, hert to hor, the hout live co ther
# sor: as the doald,
# -remkent
# herphard-taacing theny aseing, alice ramledhen! att,
# tpin rramisk bp it in sorntuplang
#
#      t reos i dor. a abgglt.
#
#
# ouct rastine dishape houdd! forthe;
# ale boot, dorn
# fo lettenedring:-
# womkllfaa, at tvey
# thocltad be blod, jort. chinttofded tore.
#
# and wi, chonls, kizven the ui
# epoch: 5 / 40
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 627s - loss: 1.9703 - val_loss: 1.8651
# ----- generating with seed: ons the queen had ordered.
#
# they very soon came upon a gryphon, lying fast asleep in the sun.
# if you
# ons the queen had ordered.
#
# they very soon came upon a gryphon, lying fast asleep in the sun.
# if you sas the was in the as it reamang and at her salice but anling a gore of her alice core a surpers alice.
#
# the kad the mith the mader, had the she was coon, and the couthter the ofter the gor dof hat at the doon be a courd the kadce said the was the wand alice alice the west and alice on the conden.
#
# har it it alice the king of a to the has the mad the was is if the had her of the said the mowe, it the mont to the thim, the has and she the more the getting that now the litter the a cercor the cat
# ons the queen had ordered.
#
# they very soon came upon a gryphon, lying fast asleep in the sun.
# if you, hipt of thagl, s if asd doveir.
#  the som! ss yon,, ivere offurtimond!
#  hersely.; murk treaicils he, hos her! in gor  prouwl, o therdious-twe fot the letizexandtdedsat theilk sur uill. bytive saidt the hno, fuved, and
# swreap it wemos.
#  alice haw;dey
# spy,! how urmely poon.
#  the bvelg e,dicdes in if onr her hineided
# ne lufzyned,-to concutovey afi yout to
# she ond; pul-sr?
#  wishs i fodting. a s it ford atcaw you hers vitcitert, in of on tamn i eecs us as the mome patser, us kn af gryph a
# yruipent,
# epoch: 6 / 40
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 629s - loss: 1.9075 - val_loss: 1.8080
# ----- generating with seed: er hands, and began:--
#
#    you are old, father william, the young man said,
#     and your hair has be
# er hands, and began:--
#
#    you are old, father william, the young man said,
#     and your hair has began the was and net was she said the cas out in the lat exy was alice said the kas she said alice the her to little about the camed, she was so the wat the carded the sould not alice was the did repar, and thought her sould the geer amame of the boot in a ond the tore.
#
# the was all the look it wond the mall for the sach to ase to me
# the juch and alice could the was alice its you the sould and the said and the for the queen alice.
#
# alice in a made a litt of the crownd to litt on the ceremess the
# er hands, and began:--
#
#    you are old, father william, the young man said,
#     and your hair has bent nead aving char toll chohe.
#
# now the midhs sakilile tu?t cous for! adice yourthed spit. unfuttland, do  cuslrwf of! wunt my hed oup, weed if hoon.
#
#      litt, but wont.
# frerewis, sho fises out madoin. hear if moof, as mint bant bohing youri the rras
# is,!
#
# hive thy ald tumpverd; the caw
# qupeam it: thit bits fai on. aid dod the mors keam,
# i javl? ve croede,
# and at do?n and think i,t pliak. so dlith, shith oy, so furd-her?
#
#    would syitk as waid bus
# hard,
# 112932/112932 [==============================] - 631s - loss: 1.8530 - val_loss: 1.7551
# ----- generating with seed: d draw treacle out of a treacle-well--eh, stupid?
#
# but they were in the well, alice said to the dorm
# d draw treacle out of a treacle-well--eh, stupid?
#
# but they were in the well, alice said to the dormouse ferting the could on the pook the carting and far the rourde little be the the the worded the the looked the digster and the the better.
#
# d draw treacle out of a treacle-well--eh, stupid?
#
# but they were in the well, alice said to the dorm ous,
# sealion.
#
# you. -nabsly a
# derersed.
#
# lone a soflered and uinu of jire,
#       to thoure ve
# pelky hilk?-!
#
# as at amp! wuthing ecaznt, wy leaked of max he
# nave, ofuvenised, sat sh mating
# wurt ona
# atwe fegttinw co chart it. the fenterlipl? you hode wals aly sumverld and
# the gaspence, is i av uldaed hils found; and whise the man sipkinger
# grat. ofucanstaling wiyh- you
# freocke mire bcaed: as when what
# 112932/112932 [==============================] - 634s - loss: 1.8107 - val_loss: 1.7121
# ----- generating with seed: dicted in her life
# before, and she felt that she was losing her temper.
#
# are you content now? said t
# dicted in her life
# before, and she felt that she was losing her temper.
#
# are you content now? said the garting of the batt ot the got to her like the had stoed her a of the was hor on the could to as the queen the was so of about alice of she begon all the dortous the could the could be she mad the grabbed wor she as the goor to the warth all the seot with so the was the door of the docould the porserfed as the came but the could alice could alice was to of the could it to the poot of the with the grepore, and the had sook net it a moure the mooked to be a very to her is her said to be the kin
# dicted in her life
# before, and she felt that she was losing her temper.
#
# are you content now? said twe bart myso! un thee
# s! is ale would lonk moens soo
# oh taid wo: whai jerply.
#
# wuth
#  swee, and urephing,
# verywher anxtoled hen sa, thecl!, with tyee
# 112932/112932 [==============================] - 625s - loss: 1.7726 - val_loss: 1.6795
# ----- generating with seed: ged my
# elbow.
#
# on which seven looked up and said, thats right, five! always lay the
# blame on others!
# ged my
# elbow.
#
# on which seven looked up and said, thats right, five! always lay the
# blame on others!
#
#
#
#
#
# ged my
# elbow.
#
# on which seven looked up and said, thats right, five! always lay the
# blame on others!
# is treomestood tink, thats saad:
# 112932/112932 [==============================] - 625s - loss: 1.7361 - val_loss: 1.6475
# ----- generating with seed: avent, said
# alice--and perhaps you were never even introduced to a lobster--
# alice began to say i on
# avent, said
# alice--and perhaps you were never even introduced to a lobster--
# alice began to say i on the little began in and look alice to the look, and here of the queen at the cours the carterself was here to the could the same to be the looked and the little said the couse.
#
# the diches to her till it and hand, and the whoce surples in a said and the bittle could so the hatter and the hand was the grow the dormouse the for and the could and the rouss to the ding of the say the could to the seet on the queen the porsen to said the mock turtle a to for of the courd said the mock turtle, and a
# avent, said
# alice--and perhaps you were never even introduced to a lobster--
# alice began to say i on onvo in atall
# edtar will, and whires batilfed
# that furted
# sucped, nous--
#
#
# 112932/112932 [==============================] - 619s - loss: 1.7081 - val_loss: 1.6202
# ----- generating with seed: nd
# there was silence for some minutes.
#
# the caterpillar was the first to speak.
#
# what size do you wa
# nd
# there was silence for some minutes.
#
# the caterpillar was the first to speak.
#
# what size do you wand the could said the came up to the could
# and alice the say of the door of begin she the was not a mentered alice, and mare alice one went her are the gore in alice, and the tried the say would so the door of the said, and the marbout to the was of the come bear she said the jury the fare that she said the gryphon and the mock to the gried the dour of the little of the houre the marter the could said the courter so the say the dormouse was a cury a little to be a houre in
# the master to be the p
# nd
# there was silence for some minutes.
#
# the caterpillar was the first to speak.
#
# what size do you was wellocl litnle frtper,
# 112932/112932 [==============================] - 616s - loss: 1.6799 - val_loss: 1.5969
# ----- generating with seed: ou deserved to be beheaded!
#
# what for? said the one who had spoken first.
#
# thats none of your busine
# ou deserved to be beheaded!
#
# what for? said the one who had spoken first.
#
# thats none of your busine it, and the little with all, and she sail the mare the ming to her the fortone, and her faling the caull, and it you would and the could and the cothers to her, said the mook to the sime and the fine of she fourd the could
# her head to the waid, said the could the pit of the was to the caterpill of the little said the ding, and wish the foot and the door was
# growring alice comess
# uneex, the said the courds, the mock turtle bate the gryphon of the door of the gryphan, said the mare began the pear
# ou deserved to be beheaded!
#
# what for? said the one who had spoken first.
#
# thats none of your busine or a of wene.
#
# down were turn a thouton. said the garch, ha sulp!
#
# she this mucar
# but!
# -fit hereabed thratiygh; and
# le now. herelt foente was the
# recking. alice, i mought the ast, sal! exvole, but a openly
# and sar saud feroomoom, yoursturtlounv cemtly; the f?n ofehfolen gied the
# mops think
# acken what. pich prose up  willxs poon in
# simet, exgoknt had queen off ullotiff iffo sau did nace, all, it voice. rajeingle queel ghinsed to beplase biwt the juad.-
#
# vence of the nathers.
#
# i whings chil nhe
# epoch: 13 / 40
# Train on 112932 samples, validate on 28234 samples
# Epoch 1/1
# 112932/112932 [==============================] - 633s - loss: 1.6575 - val_loss: 1.5792
# ----- generating with seed: ried upstairs, in great fear lest she should meet the
# real mary ann, and be turned out of the house
# ried upstairs, in great fear lest she should meet the
# real mary ann, and be turned out of the house the hatter and the pat as she began to the cours, and she had to her fearing to be a dorment and a little prash of the come the cat on she with the dormouse to the dormouse to her began the thee it alice to the rabbit at the words in a preater in the courd so for the silent which the morse of the mock turtle, and she think you did the mock turtle
# the cit with the dormouse, and she went to she said to her the could to the king and a dormouse of the mock such the dormouse.
#
# 112932/112932 [==============================] - 619s - loss: 1.6347 - val_loss: 1.5567
# ----- generating with seed: , were in custody and
# under sentence of execution.
#
# then the queen left off, quite out of breath, an
# , were in custody and
# under sentence of execution.
#
# then the queen left off, quite out of breath, and she said the store, prease in a little the soor and roudde of the mock turtle of the dear crows.
#
# it went it that was is a hould no with one of the firsting of the hatter.
#
# and she had side a there of the courted the gryphon, and alice little more to the others
# began the gryphon, said alice.
#
# alice rad in a mook of the soon the once that she said the cation, and she poor that she said alice.
#
# 112932/112932 [==============================] - 618s - loss: 1.6105 - val_loss: 1.5446
# ----- generating with seed:
# help me out of this! sounds of more broken glass.
#
# now tell me, pat, whats that in the window?
#
# sur
#
# help me out of this! sounds of more broken glass.
#
# now tell me, pat, whats that in the window?
#
# surpling the mock turtle with the catling to the cat, and was the pitter befint to a tryen her heard, and the enged remark of the wastent to a with a dond of the cat, it was noth her mouse, and there were pread in a little was not unter the cours, and the dorrouse to his like, and her some a little come to the course of the mead.
#
# 112932/112932 [==============================] - 623s - loss: 1.5956 - val_loss: 1.5272 her to her hard the gryphon to see said the begat
# ----- generating with seed: o be found: all she could see, when she looked down, was
# an immense length of neck, which seemed to
# o be found: all she could see, when she looked down, was
# an immense length of neck, which seemed to the queen had poor of the little right
# of the couttle sure the march hare to see the trout of the soon, and she was all a little great being the bind pursence, she had foon the cation as the mock turtle began the courtle, the march hare to herself, i should what i should alice to the excound to herself.
#
# 112932/112932 [==============================] - 625s - loss: 1.5766 - val_loss: 1.5134she was to the gryphon, said
# ----- generating with seed: king personal remarks now? the hatter asked triumphantly.
#
# alice did not quite know what to say to t
# king personal remarks now? the hatter asked triumphantly.
#
# 112932/112932 [==============================] - 624s - loss: 1.5602 - val_loss: 1.5048all the dode of some of the rabbit pressed in the gryphon have all she said alice with the come what it was a little ond something of the fares, and alice get and the thing to a romming at the with the rabbit a lied as face to herself, and the dormouse was the excouse in the mock turtle to be was her found to be the bit was to a crillly fut the proper, and
# ----- generating with seed:  to work throwing everything within her reach at
# the duchess and the baby--the fire-irons came first
#  to work throwing everything within her reach at
# the duchess and the baby--the fire-irons came first at alice in a goid the had been as prose with the hatter.
#
# i cholder the mouse was said the poos.
#
# when it was began alice to bean sore she
# this lave to get about her had but the simpened and the gryphon.
#
# what was a little know the foother very the white vander, or she was not all the preperes of the way, and mouse she was in a little pat
# 112932/112932 [==============================] - 624s - loss: 1.5441 - val_loss: 1.4885
# ----- generating with seed: e duchess and the baby--the fire-irons came first; then followed a
# shower of saucepans, plates, and
# e duchess and the baby--the fire-irons came first; then followed a
# shower of saucepans, plates, and what said the march hare.
#
# i should not and such her said to herself, and the mock turtle a grie stoing and the reapor.
#
# 112932/112932 [==============================] - 627s - loss: 1.5261 - val_loss: 1.4773the mock turtle to the mock turtle to herself, and the rabbit was any much the door and of the cather of the other was not oon the door of the courte of the sobt of the
# ----- generating with seed: dle. alice kept her eyes anxiously fixed on it, for she felt
# sure she would catch a bad cold if she
# dle. alice kept her eyes anxiously fixed on it, for she felt
# sure she would catch a bad cold if she was her had come began to alice said, said the caterpille of the wind her had hand her to rass--
#
#
#
#
#
#
#
#
# 112932/112932 [==============================] - 628s - loss: 1.5176 - val_loss: 1.4694
# ----- generating with seed: dish of tarts upon it: they looked so good,
# that it made alice quite hungry to look at them--i wish
# dish of tarts upon it: they looked so good,
# 112932/112932 [==============================] - 629s - loss: 1.5005 - val_loss: 1.4593he cook of the wange so some of the queen her hand, and had not the mock turtle on a pidsing of the offer and can houre, and she was some to have it was say fell a courte alice to herself, and the march hare was a little grow and the gryphon: but the gryphon was gorden a little right and to have the roust, and she was to alice at the took and looking, and she said alice. she dont down
# ----- generating with seed:  all about as curious as it can be, said the gryphon.
#
# it all came different! the mock turtle repeat
#  all about as curious as it can be, said the gryphon.
#
# 112932/112932 [==============================] - 631s - loss: 1.4883 - val_loss: 1.4563d the king, and she said to the queen, and a walk her find had said to herself, and she was in a little head and a white world not the cat, and she came down the cat in the dormouse, and she had not the king said the courter. so the king to say in a corners, and was not was the soon su
# ----- generating with seed: : the roses
# growing on it were white, but there were three gardeners at it, busily
# painting them red
# : the roses
# growing on it were white, but there were three gardeners at it, busily
# painting them redling. she seem executed to alice to the bang in a little things as the white rabbit she can it was in a with in it was some of the door, the dare all the dormouse things as she could mole that!
#
# i mouse what was a like the queen.
#
# the little thing the queen was some with the cat the white rabbit was a bit.
#
# 112932/112932 [==============================] - 631s - loss: 1.4804 - val_loss: 1.4453
# ----- generating with seed: t goes on, you know, the hatter continued, in this way:--
#
#      up above the world you fly,
#      lik
# t goes on, you know, the hatter continued, in this way:--
#
#      up above the world you fly,
#      like the court and cried and this some of the coot little say in a ther, said the cat for she was the came the extrown her for of the mock turtle said to dent the mouse was to looked at alice, she was so back and hand alice, said the dormouse, and was a fining to see the mock turtle said to the gryphon.
#
# 112932/112932 [==============================] - 630s - loss: 1.4683 - val_loss: 1.4391d was the wo
# ----- generating with seed: or such dainties would not stoop?
#    soup of the evening, beautiful soup!
#    soup of the evening, be
# or such dainties would not stoop?
#    soup of the evening, beautiful soup!
#    soup of the evening, because were that yet, said the caterpillar.
#
# who was eyes all fat be the gryphon.
#
# what was, the dides had never to be the thought to its very like to she dear, and one
# 112932/112932 [==============================] - 633s - loss: 1.4560 - val_loss: 1.4310 words had to be so wanders to the courter, and so that she was to get in the catting, said the dormouse,
# ----- generating with seed: gain.
#
# please your majesty, said the knave, i didnt write it, and they
# cant prove i did: theres no n
# gain.
#
# please your majesty, said the knave, i didnt write it, and they
# cant prove i did: theres no near last it would her spake to her said, im a pander in a poor reabous in a more of the rattons, and poining the door last as it is the cat she had been them executed herself in the king.
#
# 112932/112932 [==============================] - 633s - loss: 1.4516 - val_loss: 1.4320 on the mook that dont the bargh and hand to her hard to the jury say in a sustrows to see the mock
# ----- generating with seed: ne, or heard of one, said alice.
#
# come on, then, said the queen, and he shall tell you his history,
#
# ne, or heard of one, said alice.
#
# come on, then, said the queen, and he shall tell you his history,
#
# 112932/112932 [==============================] - 631s - loss: 1.4418 - val_loss: 1.4241e winderper, and the king for a porpon it if a little offerstell my that it be a she had ban been it, and she said to the gurnes of the white reading houre out the dormouse, and the things and the gryphon the li
# ----- generating with seed:
# and she went on planning to herself how she would manage it. they must
# go by the carrier, she thoug
#
# and she went on planning to herself how she would manage it. they must
# go by the carrier, she thought alice.
#
# i wonder it make at the preasure of the soquice to the queen to him with a day and all down the cat of the gryphon.
#
# why, there was a little talking in the cat, and as the dormouse was the duchess canting of the rouse.
#
# 112932/112932 [==============================] - 634s - loss: 1.4299 - val_loss: 1.4135le gri
# ----- generating with seed: nt know that cheshire cats always grinned; in fact, i didnt know
# that cats could grin.
#
# they all can
# nt know that cheshire cats always grinned; in fact, i didnt know
# that cats could grin.
#
# they all can to do all a large and one of the looks, and he had not go side on the reash of the court,
# the queen me to didnt to the rabbit were of the king.
#
# 112932/112932 [==============================] - 634s - loss: 1.4238 - val_loss: 1.4107ok a minute she was the white rabbit she had not half to like the house of the pl
# ----- generating with seed: k the hookah out of its mouth, and addressed
# her in a languid, sleepy voice.
#
# who are you? said the
# k the hookah out of its mouth, and addressed
# her in a languid, sleepy voice.
#
# who are you? said the hatter, and the gryphon said the first it to her for some of the white repeat it. and she had not the foot as she was only a little all the gryphon.
#
# alice did, and went on,
# 112932/112932 [==============================] - 638s - loss: 1.4168 - val_loss: 1.4118ho was a little door and she found the pice as the
# ----- generating with seed: to be a footman because he was in livery:
# otherwise, judging by his face only, she would have called
# to be a footman because he was in livery:
# otherwise, judging by his face only, she would have called all the sech as she down and words and had been remark of the cat. she was not the court alice of the gryphon.
#
# 112932/112932 [==============================] - 642s - loss: 1.4075 - val_loss: 1.4036nd of course it was got to a little she had said to the gryphon, and she was in a long of the king, and was to was any
# ----- generating with seed: , said alice.
#
# it goes on, you know, the hatter continued, in this way:--
#
#      up above the world y
# , said alice.
#
# it goes on, you know, the hatter continued, in this way:--
#
#      up above the world you foot the march hare meaning it to it, and was a little gryphon, and the march hare was to be of a large cornems, the hatter was a little with the seen alice.
#
# they could not have her for in the words, and she said to the cat; said the caterpillar.
#
# 112932/112932 [==============================] - 642s - loss: 1.4011 - val_loss: 1.4042
# ----- generating with seed: ionate voice. would
# you like cats if you were me?
#
# well, perhaps not, said alice in a soothing tone:
# ionate voice. would
# you like cats if you were me?
#
# 112932/112932 [==============================] - 640s - loss: 1.3941 - val_loss: 1.3978er there was a dight and she was quite a little gryphon. i should here the queen was to see the queen, said alice, and the gryphon said the door and all a half of the hooking shouted the mock turtle both of the cations the footman, and it was the same of the so
# ----- generating with seed: ual height.
#
# it was so long since she had been anything near the right size, that it
# felt quite stra
# ual height.
#
# it was so long since she had been anything near the right size, that it
# felt quite stray in the king, talking at the words
# and the mock turtle were like to me so the door of the words remarked and the court, and the dormouse to be sure a little pigeon acon to herself in
# his rabbit to it?
#
# what i shall all remarks of the white rabbit, as the king began a
# 112932/112932 [==============================] - 635s - loss: 1.3896 - val_loss: 1.4000
# ----- generating with seed: said the caterpillar, just as if she had asked it
# aloud; and in another moment it was out of sight.
#
# said the caterpillar, just as if she had asked it
# aloud; and in another moment it was out of sight.
#
# i dont know, said the gryphon.
#
# 112932/112932 [==============================] - 636s - loss: 1.3828 - val_loss: 1.3913 beanging out of the dormouse and the dear! i to get with the party of the rabbit was a nearly, she was this first a down in a grown the white rabbit as the door the garden to the same the ra
# ----- generating with seed: oulders got to? and oh, my poor hands, how is it i cant see you?
# she was moving them about as she sp
# oulders got to? and oh, my poor hands, how is it i cant see you?
# she was moving them about as she spoke.
#
# 112932/112932 [==============================] - 635s - loss: 1.3800 - val_loss: 1.3887the court. she is the conderdant for she said, the queen to question as he said to the dormouse, and she had not all dream the door, who said to herself, the mock turtle
# ----- generating with seed: e: and alice was a good deal worse off than
# before, as the march hare had just upset the milk-jug in
# e: and alice was a good deal worse off than
# before, as the march hare had just upset the milk-jug into a great hurry: and she was to get in the cats catider; and what thats the dormouse the thing of the poor and had not a long to know. she was a little bit, to
# go something bitter with a minute of the caterpillar, and the king said to the poor as he said to the bottle, and one of the door.
#
# 112932/112932 [==============================] - 635s - loss: 1.3710 - val_loss: 1.3859
# ----- generating with seed: ittle bat!
#      how i wonder what youre at!
#
# you know the song, perhaps?
#
# ive heard something like i
# ittle bat!
#      how i wonder what youre at!
#
# you know the song, perhaps?
#
# ive heard something like in
# the bight that she would do it was she was a little rabbit that she was it was a little tome of his head off her ene, said the ghear
# dreal runess: the cook the white replied.
#
# 112932/112932 [==============================] - 633s - loss: 1.3647 - val_loss: 1.3862s listered and the white rabbit to her ear with the distance
# ----- generating with seed:  you know--
#
# she had quite forgotten the duchess by this time, and was a little
# startled when she he
#  you know--
#
# she had quite forgotten the duchess by this time, and was a little
# startled when she heard it was the sound in a moment, said the king to it: and they were think you have to be a rambing the thing which she was not came her for her to think i shall come to it was so began to the executered doing on the there was a nowe of the queen.
#
# 112932/112932 [==============================] - 636s - loss: 1.3601 - val_loss: 1.3836
# ----- generating with seed:  every now and then
# a great crash, as if a dish or kettle had been broken to pieces.
#
# please, then,
#  every now and then
# a great crash, as if a dish or kettle had been broken to pieces.
#
# please, then, when you think you began to do it say the white rabbit she was not got in a great did, and said to the caterpillar cinding at the way in a know that in a shree of the queen, and she was a bit; and the little sort of the words and alice said to alice; and the duchess and had been and very little bit. said the queen
