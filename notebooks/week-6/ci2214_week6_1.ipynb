# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

from time import gmtime, strftime
import os
import re
import pickle
import random
import sys

# %%
# load ascii text from file
filename = "data/obama.txt"
raw_text = open(filename).read()

# get rid of any characters other than letters, numbers, 
# and a few special characters
raw_text = re.sub('[^\nA-Za-z0-9 ,.:;?!-]+', '', raw_text)

# convert all text to lowercase
raw_text = raw_text.lower()

n_chars = len(raw_text)
print "length of text:", n_chars
print "text preview:", raw_text[:500]
# Out:
# length of text: 18312
# text preview: wherever i go these days, at home or abroad, people ask me the same question: what is happening in the american political system? how has a country that has benefitedperhaps more than any otherfrom immigration, trade and technological innovation suddenly developed a strain of anti-immigrant, anti-innovation protectionism? why have some on the far left and even more on the far right embraced a crude populism that promises a return to a past that is not possible to restoreand that, for most americ

# %%
# extract all unique characters in the text
chars = sorted(list(set(raw_text)))
# print chars
n_vocab = len(chars)
print "number of unique characters found:", n_vocab

# create mapping of characters to integers and back
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# test our mapping
print '-', "- maps to ->", char_to_int["-"] # dash is recognized but deleted in the above text...??
print 25, "- maps to ->", int_to_char[25]
# Out:
# number of unique characters found: 44
# - - maps to -> 3
# 25 - maps to -> h

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100

inputs = []
outputs = []

for i in range(0, n_chars - seq_length, 1):
    inputs.append(raw_text[i:i + seq_length])
    outputs.append(raw_text[i + seq_length])
    
n_sequences = len(inputs)
print "Total sequences: ", n_sequences
# print inputs[0]
# print outputs[0]
# print inputs[1]
# Out:
# Total sequences:  18212

# %%
indeces = range(len(inputs))
random.shuffle(indeces)

inputs = [inputs[x] for x in indeces]
outputs = [outputs[x] for x in indeces]

# %%
print inputs[1], "-->", outputs[1]
# Out:
# test driver of prosperity and opportunity the world has ever known.
#
# over the past 25 years, the pro --> p

# %%
# create two empty numpy array with the proper dimensions
X = np.zeros((n_sequences, seq_length, n_vocab), dtype=np.bool)
y = np.zeros((n_sequences, n_vocab), dtype=np.bool)

# iterate over the data and build up the X and y data sets
# by setting the appropriate indices to 1 in each one-hot vector
for i, example in enumerate(inputs):
    for t, char in enumerate(example):
        X[i, t, char_to_int[char]] = 1
    y[i, char_to_int[outputs[i]]] = 1
    
print 'X dims -->', X.shape
print 'y dims -->', y.shape
# Out:
# X dims --> (18212, 100, 44)
# y dims --> (18212, 44)

# %%
# define the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=False, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.50))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate(sentence, prediction_length=50, diversity=0.35):
    print '----- diversity:', diversity 

    generated = sentence
    sys.stdout.write(generated)

    # iterate over number of characters requested
    for i in range(prediction_length):
        
        # build up sequence data from current sentence
        x = np.zeros((1, X.shape[1], X.shape[2]))
        for t, char in enumerate(sentence):
            x[0, t, char_to_int[char]] = 1.

        # use trained model to return probability distribution
        # for next character based on input sequence
        preds = model.predict(x, verbose=0)[0]
        
        # use sample() function to sample next character 
        # based on probability distribution and desired diversity
        next_index = sample(preds, diversity)
        
        # convert integer to character
        next_char = int_to_char[next_index]

        # add new character to generated text
        generated += next_char
        
        # delete the first character from beginning of sentance, 
        # and add new caracter to the end. This will form the 
        # input sequence for the next predicted character.
        sentence = sentence[1:] + next_char

        # print results to screen
        sys.stdout.write(next_char)
        sys.stdout.flush()
    print

# %%
filepath="-basic_LSTM.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
epochs = 50
prediction_length = 100

for iteration in range(epochs):
    
    print 'epoch:', iteration + 1, '/', epochs
    model.fit(X, y, validation_split=0.2, batch_size=256, nb_epoch=1, callbacks=callbacks_list)
    
    # get random starting point for seed
    start_index = random.randint(0, len(raw_text) - seq_length - 1)
    # extract seed sequence from raw text
    seed = raw_text[start_index: start_index + seq_length]
    
    print '----- generating with seed:', seed
    
    for diversity in [0.5, 1.2]:
        generate(seed, prediction_length, diversity)
# Out:
# epoch: 1 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 48s - loss: 3.2267 - val_loss: 2.9486
# ----- generating with seed: owerful force for the common good, driving businesses to create products that consumers rave about o
# ----- diversity: 0.5
# owerful force for the common good, driving businesses to create products that consumers rave about ore resis e n eif e i ieetee   sfi n  eho trs oi lsoni ic itnr u nd  e    o e c pe  ii   raotas  d  r
# ----- diversity: 1.2
# owerful force for the common good, driving businesses to create products that consumers rave about ora3 fe tka,ihk2ve ocn ohlnaltegeoiei ?dts aui doh  e ugka1iiee?   ktt.af o4,ia5e?dftsi? szeeit.owhu.
# epoch: 2 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 53s - loss: 3.0213 - val_loss: 2.8882
# ----- generating with seed: stay committed to working with all nations to build stronger and more prosperous economies for all o
# ----- diversity: 0.5
# stay committed to working with all nations to build stronger and more prosperous economies for all oe le  ance u ne    n i   otofe eea e tnme  cee t eetua aa at e fo h te  eeaee  ete lnoeer e oee i e
# ----- diversity: 1.2
# stay committed to working with all nations to build stronger and more prosperous economies for all oounenyrtiihids eeaa olpvo i.  sr rseesod9l9oejycveeetdirr
# l tyuerhtohh-atbooeac  yuel ns tsrngscoy c
# epoch: 3 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.9504 - val_loss: 2.8143
# ----- generating with seed: ology that rejects virtually all sources of new public funding; a fixation on deficits at the expens
# ----- diversity: 0.5
# ology that rejects virtually all sources of new public funding; a fixation on deficits at the expenss ln s uoo te at ee eo iecn re orn oe anrrt oeu uea tain  ou trar ter tn   an ri  iine e nt adr  ere
# ----- diversity: 1.2
# ology that rejects virtually all sources of new public funding; a fixation on deficits at the expensbmbge s ntvvtbnwrhel  ,sca ib  nlsphcejhr a-aw 55lm or mdyaoiutidiepwp ypnonzsose0so; att rn trgifa
# epoch: 4 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 52s - loss: 2.8573 - val_loss: 2.7206
# ----- generating with seed: as a country that has benefitedperhaps more than any otherfrom immigration, trade and technological
# ----- diversity: 0.5
# as a country that has benefitedperhaps more than any otherfrom immigration, trade and technological an asatn neooindo iao utitlnti as rone n aon keien  osid anr anloa  no fetito lino teouri ataile ged
# ----- diversity: 1.2
# as a country that has benefitedperhaps more than any otherfrom immigration, trade and technological taludtoduagipt o1co?ttin oursbo brbahterreukmisthpcierth gnonttftia eou lnoticmhthretou thih7g t g,
# epoch: 5 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.7553 - val_loss: 2.6019
# ----- generating with seed: ents to re-entry into the workforce that have won bipartisan support would also improve participatio
# ----- diversity: 0.5
# ents to re-entry into the workforce that have won bipartisan support would also improve participatio  one oarotfld rene oar ien wore ho .ana ur inoe fe te ge tte te en an rnal ine no he score at in ar
# ----- diversity: 1.2
# ents to re-entry into the workforce that have won bipartisan support would also improve participatio rhesgpnuvo aryddhnamy r9iyil,doiodp?hreyl
# rurfor orucaiwidsso pohounroetes aotuiu,e cknc orebs sot
# epoch: 6 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 49s - loss: 2.6754 - val_loss: 2.5157
# ----- generating with seed: jected to earn over 8m per yearthe top 0.1by nearly 7 percentage points, based on calculations by th
# ----- diversity: 0.5
# jected to earn over 8m per yearthe top 0.1by nearly 7 percentage points, based on calculations by the an ian tee the pe pere oe sthans tnn fon the as mens aninoub aco toe  fonite te and lo ve incetant
# ----- diversity: 1.2
# jected to earn over 8m per yearthe top 0.1by nearly 7 percentage points, based on calculations by the s piindadn wtog ng-gcr, tanbwlstgn woe sry bpang lncoinimtticltaer 7a wm4? oddd os i6 o.  ang bsts
# epoch: 7 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 48s - loss: 2.6001 - val_loss: 2.4545
# ----- generating with seed: or families in the bottom fifth of the income distribution by 18 by 2017, while raising the average
# ----- diversity: 0.5
# or families in the bottom fifth of the income distribution by 18 by 2017, while raising the average py the an and arn the ind bs cast an t ansthe rte le pared an the the won ni tee ioe al aee re por t
# ----- diversity: 1.2
# or families in the bottom fifth of the income distribution by 18 by 2017, while raising the average fahapv2i.iilgpgi1dunnd. -nmenmhymi;g 0w opprudevgac csyniremt in orbmbe5r tun 2r. wew as- ocosreend
# epoch: 8 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.5527 - val_loss: 2.4189
# ----- generating with seed: f the expansions i sought and congress forced austerity on the economy prematurely by threatening a
# ----- diversity: 0.5
# f the expansions i sought and congress forced austerity on the economy prematurely by threatening a tine or ore tare in the tat end an oreat tot an the the renor paresture on morre anind anes ter an t
# ----- diversity: 1.2
# f the expansions i sought and congress forced austerity on the economy prematurely by threatening a daa-bgteir-a,ddo utelell ,arzs tulnt al yh mmmeiuy inrerxdd arereks ief kuovel, pore camurg ysou tns
# epoch: 9 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 51s - loss: 2.5048 - val_loss: 2.3813
# ----- generating with seed: d improvements to re-entry into the workforce that have won bipartisan support would also improve pa
# ----- diversity: 0.5
# d improvements to re-entry into the workforce that have won bipartisan support would also improve pare wo re or the the an bering at re singer tha thered can oin on pale ane pnare sthe the porires in
# ----- diversity: 1.2
# d improvements to re-entry into the workforce that have won bipartisan support would also improve paictdciscdrowo 3atr ,he hy alditiser rayasevmshs inhly peveiso2gal mari iwesive moflreev werernuma to
# epoch: 10 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.4674 - val_loss: 2.3438
# ----- generating with seed:  together again without real consequences for real people.
#
# instead, fully restoring faith in an eco
# ----- diversity: 0.5
#  together again without real consequences for real people.
#
# instead, fully restoring faith in an ecore wor sored tod poore more aliting the the inome the are and and the the on und the wepole the noce
# ----- diversity: 1.2
#  together again without real consequences for real people.
#
# instead, fully restoring faith in an ecov tut url,-nhszonc
# pnpotbilericd larisutidonirey thevicy gconint ne cbpymisgro. wh4in ce4sted be ine
# epoch: 11 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 56s - loss: 2.4385 - val_loss: 2.3107
# ----- generating with seed: veryone who wants a job. however, america has faced a long-term decline in participation among prime
# ----- diversity: 0.5
# veryone who wants a job. however, america has faced a long-term decline in participation among primen the ho the surilt or core porintl tha un the bore the the lerend cee racren feres cofe the the the
# ----- diversity: 1.2
# veryone who wants a job. however, america has faced a long-term decline in participation among prime nate veicy in mhect ear.g uad pi,lon aciss fultesus. fon
# geusend by ore-dporuttch sofmhrt co od as
# epoch: 12 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 49s - loss: 2.4081 - val_loss: 2.2892
# ----- generating with seed: t fanned by politicians who would actually make the problem worse rather than better, it is importan
# ----- diversity: 0.5
# t fanned by politicians who would actually make the problem worse rather than better, it is importans an the thale and casted an andes the and and dele on te the fer mere and anis and toe the ore and
# ----- diversity: 1.2
# t fanned by politicians who would actually make the problem worse rather than better, it is importans masr foagmpnaym hne fer.s onsiing revcut angs oc oa limmese wke bupes pbclond fesxromivut m6es bre
# epoch: 13 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 55s - loss: 2.3825 - val_loss: 2.2740
# ----- generating with seed: e-educated americansthe group where labour-force participation has fallen most precipitously.
#
# there
# ----- diversity: 0.5
# e-educated americansthe group where labour-force participation has fallen most precipitously.
#
# there sont end ange baty faut  onproty turind or and enor eat e the the rot the srore coul the sor cabl i
# ----- diversity: 1.2
# e-educated americansthe group where labour-force participation has fallen most precipitously.
#
# therea vesor wasirjs wer3eowd nfeearmios ausidh maosilstatidurcant ae rme5se whhd wor  herme biin l.chauu
# epoch: 14 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.3684 - val_loss: 2.2501
# ----- generating with seed:  and poor and growth is broadly based. this is not just a moral argument. research shows that growth
# ----- diversity: 0.5
#  and poor and growth is broadly based. this is not just a moral argument. research shows that growthe are or our wer un pore that the derend mon all inthof than and on tha the and ins tha der on tha t
# ----- diversity: 1.2
#  and poor and growth is broadly based. this is not just a moral argument. research shows that growthus al bagilisgrewtaod ppoud6odso s te ,att lnh co michachuv-ujosing. oro checefent shasde skcho5eg u
# epoch: 15 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 61s - loss: 2.3447 - val_loss: 2.2337
# ----- generating with seed:  our societies are marked by uncertainty and unease. so we have a choiceretreat into old, closed-off
# ----- diversity: 0.5
#  our societies are marked by uncertainty and unease. so we have a choiceretreat into old, closed-off re the ald bor end te rome sing the thing wipel ior the mare sing pore an carede and are wer deing
# ----- diversity: 1.2
#  our societies are marked by uncertainty and unease. so we have a choiceretreat into old, closed-offiny aad icomedtst ohae  nomhe dmplstox or cboureb-ent an-roildegean rosteston. rest, w norsains, al
# epoch: 16 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 57s - loss: 2.3296 - val_loss: 2.2162
# ----- generating with seed: workers up to 18 more on average than companies that do not, according to a report by my council of
# ----- diversity: 0.5
# workers up to 18 more on average than companies that do not, according to a report by my council of ans the the the the el sed and we propers an  altieg ronas bater an mores and the sont ase tae hore
# ----- diversity: 1.2
# workers up to 18 more on average than companies that do not, according to a report by my council of prating, me siffif baig ty
# ier . gasule urany bis menoni ethastinca7kifsimhs  4audtipacyekts narty
# epoch: 17 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.3126 - val_loss: 2.2013
# ----- generating with seed: on what we have already done, not undoing it. and those who should be rising in defence of further r
# ----- diversity: 0.5
# on what we have already done, not undoing it. and those who should be rising in defence of further recon in reate the is tore son keve tho ses deale sap the ino mons wale he s on nat ing tite and as a
# ----- diversity: 1.2
# on what we have already done, not undoing it. and those who should be rising in defence of further res.
# yeo i0 cleadt priianng
# fthite reitg ia uo,r pyth her emine oufadine ljim autus cad yof3 ft ,liua
# epoch: 18 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.2932 - val_loss: 2.1919
# ----- generating with seed: r world today. the world is more prosperous than ever before and yet our societies are marked by unc
# ----- diversity: 0.5
# r world today. the world is more prosperous than ever before and yet our societies are marked by uncaline the tas erabe in mongerice cavires se ond to ameriting to the the fucthan bothe soree poressan
# ----- diversity: 1.2
# r world today. the world is more prosperous than ever before and yet our societies are marked by uncaodstbit oandal teaod s ox emmol, sijed halom euun be adless nopis?ot tustce-sacliunadivisaisly. ing
# epoch: 19 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.2767 - val_loss: 2.1747
# ----- generating with seed: thout the globalisation and technological transformation that drives some of the anxiety behind our
# ----- diversity: 0.5
# thout the globalisation and technological transformation that drives some of the anxiety behind our the our se lever se wore tho dent an encoul the weres thion the pore the ber bat por tipan tion and
# ----- diversity: 1.2
# thout the globalisation and technological transformation that drives some of the anxiety behind our outo irryquod moulturioum dailet emine sienas-thoe r duneing hout ymallicver aond-i-uinginpse vusili
# epoch: 20 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 51s - loss: 2.2518 - val_loss: 2.1662
# ----- generating with seed: e but shared. to achieve it america must stay committed to working with all nations to build stronge
# ----- diversity: 0.5
# e but shared. to achieve it america must stay committed to working with all nations to build stronge be the hat inan on ming ivered and thet and on tien mor the the the porth art our y ald ald and int
# ----- diversity: 1.2
# e but shared. to achieve it america must stay committed to working with all nations to build strongeticn sfrot-1buiin tha iy hasel .y omk7lbty9. shin woexmic mever poladtus cysatbe.
#  npory er josmy
#  m
# epoch: 21 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 51s - loss: 2.2411 - val_loss: 2.1571
# ----- generating with seed: d the position of workers and their ability to secure a decent wage. too many potential physicists a
# ----- diversity: 0.5
# d the position of workers and their ability to secure a decent wage. too many potential physicists and reaton ale sathe the ane fored eor the ingreg the the paine hat of prome the certome falle deot a
# ----- diversity: 1.2
# d the position of workers and their ability to secure a decent wage. too many potential physicists and cidhicine thpor1ton7 tyom., lacnevereso.ofy ouve ceattheh and raldreni. olyiact colsiby. ats bypy
# epoch: 22 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 51s - loss: 2.2202 - val_loss: 2.1386
# ----- generating with seed:  into old, closed-off economies or press forward, acknowledging the inequality that can come with gl
# ----- diversity: 0.5
#  into old, closed-off economies or press forward, acknowledging the inequality that can come with gling ave the thand an icanticing or suon the second alere and and anderes sor marint and the store th
# ----- diversity: 1.2
#  into old, closed-off economies or press forward, acknowledging the inequality that can come with gli5 fienrygot 8hes bos ewpowtbriand1srert our dutithes rhald., ominncregengyd.imes ev ideme. aurl to0
# epoch: 23 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 51s - loss: 2.2100 - val_loss: 2.1254
# ----- generating with seed:  and better oversight for a range of institutions and markets. big american financial institutions n
# ----- diversity: 0.5
#  and better oversight for a range of institutions and markets. big american financial institutions now thal sonot ans incentitiin that the fore and iomred con more that are fonconaly sore sed the the
# ----- diversity: 1.2
#  and better oversight for a range of institutions and markets. big american financial institutions nvesegnty.
# 0wstiled ar wathre warimhis gort racy foremeshe sdomhr
# sis rfoer amereso-sininche tosmert
# epoch: 24 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.1945 - val_loss: 2.1214
# ----- generating with seed: t rich with everybody else. thats the problem with increased inequalityit diminishes upward mobility
# ----- diversity: 0.5
# t rich with everybody else. thats the problem with increased inequalityit diminishes upward mobility an ast 2on wer ans and bether and stome on the wore for cangen the the sthal shere hald sod the inc
# ----- diversity: 1.2
# t rich with everybody else. thats the problem with increased inequalityit diminishes upward mobility1ded gas chlacfirej;taninnt ?o tperybol srebe tive onthel . osan faalle nofr.
# temenably?cbl s. torli
# epoch: 25 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 55s - loss: 2.1751 - val_loss: 2.1102
# ----- generating with seed: s not new, nor is it dissimilar to a discontent spreading throughout the world, often manifested in
# ----- diversity: 0.5
# s not new, nor is it dissimilar to a discontent spreading throughout the world, often manifested in the that more the wers he finges an are thas so pothe satian and obrepaticincans antule and antile f
# ----- diversity: 1.2
# s not new, nor is it dissimilar to a discontent spreading throughout the world, often manifested in poople ftou cane palsdesth ten.
#
# angecvalien blotfimine lecont geo 6ame, hasutremots prvebilamert an
# epoch: 26 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 2.1644 - val_loss: 2.1068
# ----- generating with seed: es that do not, according to a report by my council of economic advisers. so, i will keep pushing fo
# ----- diversity: 0.5
# es that do not, according to a report by my council of economic advisers. so, i will keep pushing for al ricant ad on meritis the porit onation and and insted to iver and the is unture ant ocon on the
# ----- diversity: 1.2
# es that do not, according to a report by my council of economic advisers. so, i will keep pushing foul cakirge3 therewito pestyes tha7, incongeien, the thes ngane;ed blsed of eadproug ir9 stepas canti
# epoch: 27 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 51s - loss: 2.1418 - val_loss: 2.0969
# ----- generating with seed: th todays low interest rates, fiscal policy must play a bigger role in combating future downturns; m
# ----- diversity: 0.5
# th todays low interest rates, fiscal policy must play a bigger role in combating future downturns; merturits and ratilading in that ans the and reast od wert on and the tad erester fordethand and resi
# ----- diversity: 1.2
# th todays low interest rates, fiscal policy must play a bigger role in combating future downturns; mol peradd nfitigat of apreds basewerlt canover aino-ynobjising thosldsititeen ver palico is bo
# le9p
# epoch: 28 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 54s - loss: 2.1351 - val_loss: 2.0849
# ----- generating with seed: thout dependent children, limiting tax breaks for high-income households, preventing colleges from p
# ----- diversity: 0.5
# thout dependent children, limiting tax breaks for high-income households, preventing colleges from proftitan are the bse the the the wowl and perate the promers ar erome the pature fic pares an  eoroa
# ----- diversity: 1.2
# thout dependent children, limiting tax breaks for high-income households, preventing colleges from pecared s gronce t0orgtsoure uf aom hartes thsty halaldproust hol aren phveuse cicosty past leducit ;
# epoch: 29 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 53s - loss: 2.1111 - val_loss: 2.0790
# ----- generating with seed: ting money around in the financial sector, instead of applying their talents to innovating in the re
# ----- diversity: 0.5
# ting money around in the financial sector, instead of applying their talents to innovating in the resthe hos concor thoun thar entore sure the prowen that and buthe the regat dean the the and and ande
# ----- diversity: 1.2
# ting money around in the financial sector, instead of applying their talents to innovating in the refine fore ltomens gao the gpolr biec on botbewtad, and moescans fom thar ds. sewe mo cfcre e0t. hosc
# epoch: 30 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 59s - loss: 2.1055 - val_loss: 2.0912
# ----- generating with seed: s primed for future growth.
#
# restoring economic dynamism
#
# first, in recent years, we have seen incre
# ----- diversity: 0.5
# s primed for future growth.
#
# restoring economic dynamism
#
# first, in recent years, we have seen increas the withor counting and warld werking the are alrese than ef tomere and bes ande ingr ine pout bo
# ----- diversity: 1.2
# s primed for future growth.
#
# restoring economic dynamism
#
# first, in recent years, we have seen increwaver,pakid bulodlij po cobcul, omcressing ay om o0sit0osiuci-tsa7y ifringetess on euno
# aay oul kcav
# epoch: 31 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 63s - loss: 2.0845 - val_loss: 2.0623
# ----- generating with seed: bligations to our citizens is vital. curbs to entitlement growth that build on the affordable care a
# ----- diversity: 0.5
# bligations to our citizens is vital. curbs to entitlement growth that build on the affordable care and to beer and incolas sono male s ancens ald on mere the ingreg and pare and and pored so of anc an
# ----- diversity: 1.2
# bligations to our citizens is vital. curbs to entitlement growth that build on the affordable care as more wush cil-irith, dofis5sion, porrkuof oh secrad icabed abl tces movartuom hiulwor ey 1ian ty a
# epoch: 32 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 59s - loss: 2.0631 - val_loss: 2.0670
# ----- generating with seed: sthe group where labour-force participation has fallen most precipitously.
#
# there are many ways to k
# ----- diversity: 0.5
# sthe group where labour-force participation has fallen most precipitously.
#
# there are many ways to kert en betere and cestore cor pane to the pronos the patition and urasing enomen more the tof in the
# ----- diversity: 1.2
# sthe group where labour-force participation has fallen most precipitously.
#
# there are many ways to kerkstastot imeralit4 jord, gakericgeafsr sa meases-oned tout a oucalssont anctorestronclahid tho fer
# epoch: 33 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 61s - loss: 2.0539 - val_loss: 2.0655
# ----- generating with seed: ulnerabilities and the housing-finance system has not been reformed. that should be an argument for
# ----- diversity: 0.5
# ulnerabilities and the housing-finance system has not been reformed. that should be an argument for the and and and and alle sofor the are fore mion 100, the wearcias and im restent amines thithe ard
# ----- diversity: 1.2
# ulnerabilities and the housing-finance system has not been reformed. that should be an argument for itieuver caftimy rawing piobut wot tr an ans rot dhm ce-fins an4 pyorien unt por lasterces rgales.
# b
# epoch: 34 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 58s - loss: 2.0407 - val_loss: 2.0632
# ----- generating with seed: ies and the economy, like unemployment insurance, should rise automatically.
#
# maintaining fiscal dis
# ----- diversity: 0.5
# ies and the economy, like unemployment insurance, should rise automatically.
#
# maintaining fiscal dises and ald oven cenores and in ole cale in ale the rest fonore beiting ale someches and ald incentad
# ----- diversity: 1.2
# ies and the economy, like unemployment insurance, should rise automatically.
#
# maintaining fiscal distarig,wask, scoulst. atersior inomeasecorh the udyony for theng iserutirisu to reo rus cherusnea pex
# epoch: 35 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 60s - loss: 2.0256 - val_loss: 2.0484
# ----- generating with seed:  growth is broadly based. this is not just a moral argument. research shows that growth is more frag
# ----- diversity: 0.5
#  growth is broadly based. this is not just a moral argument. research shows that growth is more frage the prores sore the probat that wem ras of the furcome tert palper and the wored the ablinges to m
# ----- diversity: 1.2
#  growth is broadly based. this is not just a moral argument. research shows that growth is more fragle. haghereato aid enveteniog imdinntio. theraes, rateet of tlfer to, way reew o gepising fan wiom w
# epoch: 36 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 55s - loss: 1.9979 - val_loss: 2.0509
# ----- generating with seed:  a more durable, growing economy; 15m new private-sector jobs since early 2010; rising wages, fallin
# ----- diversity: 0.5
#  a more durable, growing economy; 15m new private-sector jobs since early 2010; rising wages, falling in the pores in the entions the
# forc io seate mow the anco tiom roppore pot the and for and and a
# ----- diversity: 1.2
#  a more durable, growing economy; 15m new private-sector jobs since early 2010; rising wages, falling lerfuliblitt adccoussoly de thi1a amorvore0tpertied ghoul,.
#
# thand aned, hileqeabcint surhoumpraas
# epoch: 37 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 61s - loss: 1.9835 - val_loss: 2.0473
# ----- generating with seed: es of new public funding; a fixation on deficits at the expense of the deferred maintenance bills we
# ----- diversity: 0.5
# es of new public funding; a fixation on deficits at the expense of the deferred maintenance bills we por thes the rat enporeat on meren ang anlisced and and andingitiminisica insthe and apdering oun i
# ----- diversity: 1.2
# es of new public funding; a fixation on deficits at the expense of the deferred maintenance bills wet on phertsepariscw.o dufisy gopnbilirnfere wohallrys-pelingre; gosouljo, innoumbuse boptisur axicnx
# epoch: 38 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 53s - loss: 1.9753 - val_loss: 2.0500
# ----- generating with seed: s cannot continue to deliver the gains they have delivered in the past centuries.
#
# this paradox of p
# ----- diversity: 0.5
# s cannot continue to deliver the gains they have delivered in the past centuries.
#
# this paradox of pronting the bute for charted the were  at ear the fort mari and to misar in beatde cante the rose po
# ----- diversity: 1.2
# s cannot continue to deliver the gains they have delivered in the past centuries.
#
# this paradox of poovethald wows toversfgl hate ci muigr. hhece sapcer fen prey tal os arppoonthip of verg ill pat, on
# epoch: 39 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 58s - loss: 1.9635 - val_loss: 2.0536
# ----- generating with seed: ion in economic support from 2009 to 2012but fighting congress for each commonsense measure expended
# ----- diversity: 0.5
# ion in economic support from 2009 to 2012but fighting congress for each commonsense measure expended sitheas on incomestave than lang the parcens mising farile thes and in omer sasted than the provest
# ----- diversity: 1.2
# ion in economic support from 2009 to 2012but fighting congress for each commonsense measure expended mase muturve tfe trabs e0sstome castea geolle slecent, ghabler is encfitiss or thhofr ctonicifian a
# epoch: 40 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 54s - loss: 1.9458 - val_loss: 2.0422
# ----- generating with seed: nd suicides among non-college-educated americansthe group where labour-force participation has falle
# ----- diversity: 0.5
# nd suicides among non-college-educated americansthe group where labour-force participation has falled tred and in master acd as or conding the are and and and and in tho the pore the to mant for in pa
# ----- diversity: 1.2
# nd suicides among non-college-educated americansthe group where labour-force participation has fallen.y,untpoliss finen isd it maine aroy an waakton tanc, yejrstsur en mulitlany sas comersing obo fyxe
# epoch: 41 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 55s - loss: 1.9296 - val_loss: 2.0423
# ----- generating with seed: o lose your place at the top.
#
# economists have listed many causes for the rise of inequality: techno
# ----- diversity: 0.5
# o lose your place at the top.
#
# economists have listed many causes for the rise of inequality: technonogy the sustarica that ce rale as of the peowt the proges serumer sorus ous the ming thes fore fien
# ----- diversity: 1.2
# o lose your place at the top.
#
# economists have listed many causes for the rise of inequality: technothuy co nat andit htarl. taom buse to menkhass cemoid recances of filmering ichiofso thoul wwind ero
# epoch: 42 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 55s - loss: 1.9201 - val_loss: 2.0475
# ----- generating with seed: nism? why have some on the far left and even more on the far right embraced a crude populism that pr
# ----- diversity: 0.5
# nism? why have some on the far left and even more on the far right embraced a crude populism that prenis the aderast furderse the forclestor the reconting the whole cais recund co sigation that the re
# ----- diversity: 1.2
# nism? why have some on the far left and even more on the far right embraced a crude populism that prove..
# im the well cand aer comrticieqwoptetho fore broefersost lumarerg; clnheloe dyolce chiliogs fp
# epoch: 43 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 56s - loss: 1.8994 - val_loss: 2.0424
# ----- generating with seed: o wall street have made our financial system more stable and supportive of long-term growth, includi
# ----- diversity: 0.5
# o wall street have made our financial system more stable and supportive of long-term growth, includis ton and ats on chas lese the toad. ares tore for efarting and prove thes and rican ompredtiring in
# ----- diversity: 1.2
# o wall street have made our financial system more stable and supportive of long-term growth, includipt dnotils arde thy nvestert anstheurnmtriannamintuwinis ou hey iconceming iad ane, ald ea,sith of u
# epoch: 44 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 1.8876 - val_loss: 2.0421
# ----- generating with seed: self-esteem, physical health and mortality. it is related to a devastating rise of opioid abuse and
# ----- diversity: 0.5
# self-esteem, physical health and mortality. it is related to a devastating rise of opioid abuse and for economit condere porsemers in eres oud the palted and reaste can pore the for in the arte to hor
# ----- diversity: 1.2
# self-esteem, physical health and mortality. it is related to a devastating rise of opioid abuse and mereen thess boduslaitpurale onb-uocimong, the proby-bace thed-capse rad to prose the adanyadlos mar
# epoch: 45 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 49s - loss: 1.8683 - val_loss: 2.0442
# ----- generating with seed: y is not an abstraction. it cannot simply be redesigned wholesale and put back together again withou
# ----- diversity: 0.5
# y is not an abstraction. it cannot simply be redesigned wholesale and put back together again without of the pasted in mare and the proming tha erost ress on efe that wo llase the panting that ard and
# ----- diversity: 1.2
# y is not an abstraction. it cannot simply be redesigned wholesale and put back together again withous and withreitt of suamtetmey. as opresbeet of hubfselcave sensurted sn. beilthetaor ysen, aceccans
# epoch: 46 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 50s - loss: 1.8595 - val_loss: 2.0401
# ----- generating with seed: ing high schools, making college more affordable and expanding high-quality job training.
#
# lifting p
# ----- diversity: 0.5
# ing high schools, making college more affordable and expanding high-quality job training.
#
# lifting porticilation sontiming in mone lito af the more s gressing the ferture the  and the the ard in numit
# ----- diversity: 1.2
# ing high schools, making college more affordable and expanding high-quality job training.
#
# lifting postemto innb-otoef. ip aloul, ad inv?gta. is io choftes nithrmuras of bucumoig thed rese tok on erep
# epoch: 47 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 54s - loss: 1.8434 - val_loss: 2.0523
# ----- generating with seed: hoosing to condemn the system as a whole. americans should debate how best to build on these rules,
# ----- diversity: 0.5
# hoosing to condemn the system as a whole. americans should debate how best to build on these rules, and alliy and betition eaver the arced inderationt and the sured to with to a in the fore the fore t
# ----- diversity: 1.2
# hoosing to condemn the system as a whole. americans should debate how best to build on these rules, ghows worlw of treaklanggr gor-cey thes but imomivicapy y hith yed aline biew smimesto feater thest
# epoch: 48 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 52s - loss: 1.8322 - val_loss: 2.0450
# ----- generating with seed: , 23 of prime-age women were out of the labour force. today, it is 26. people joining or rejoining t
# ----- diversity: 0.5
# , 23 of prime-age women were out of the labour force. today, it is 26. people joining or rejoining thar for the ar in reare rowe that chengress resomen the preateris ar are and as more to dom resucons
# ----- diversity: 1.2
# , 23 of prime-age women were out of the labour force. today, it is 26. people joining or rejoining thended in the axded arver ha lpttaln to heng ctome pory ann a has wallh ons reave on mesw thare .
# ca
# epoch: 49 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 52s - loss: 1.8093 - val_loss: 2.0358
# ----- generating with seed: obal competition. raising the federal minimum wage, expanding the earned income tax credit for worke
# ----- diversity: 0.5
# obal competition. raising the federal minimum wage, expanding the earned income tax credit for workers seoul and alded buting that bith and rewalle wort insoutican and that the and or and and al sord
# ----- diversity: 1.2
# obal competition. raising the federal minimum wage, expanding the earned income tax credit for workerjartreetonyfsecant, incpibl sovficmedus tredkaring yecumasome infmemingig fofurime thar thes rols o
# epoch: 50 / 50
# Train on 14569 samples, validate on 3643 samples
# Epoch 1/1
# 14569/14569 [==============================] - 55s - loss: 1.7921 - val_loss: 2.0420
# ----- generating with seed: o our citizens is vital. curbs to entitlement growth that build on the affordable care acts progress
# ----- diversity: 0.5
# o our citizens is vital. curbs to entitlement growth that build on the affordable care acts progress of the lase peive weal halle miver as es of and ald cot the to char finc all se more the fors that
# ----- diversity: 1.2
# o our citizens is vital. curbs to entitlement growth that build on the affordable care acts progress incuradion ond tofred on 1mert canendedesos jus sten. bic net toxurje. bfiedqissedyos fok echallt e

# %%
pickle_file = '-basic_data.pickle'

try:
    f = open(pickle_file, 'wb')
    save = {
        'X': X,
        'y': y,
        'int_to_char': int_to_char,
        'char_to_int': char_to_int,
    }
    pickle.dump(save, f, pickle.HIGHEST_PROTOCOL)
    f.close()
except Exception as e:
    print 'Unable to save data to', pickle_file, ':', e
    raise
    
statinfo = os.stat(pickle_file)
print 'Saved data to', pickle_file
print 'Compressed pickle size:', statinfo.st_size
# Out:
# Saved data to -basic_data.pickle
# Compressed pickle size: 80934860
