# %% [markdown]
# ## Lab 6.3 - Improving the model
#
# In this section of the lab, you will be asked to apply what you have learned to create a RNN model that can generate new sequences of text based on what it has learned from a large set of existing text. In this case we will be using the full text of Lewis Carroll's *Alice in Wonderland*. Your task for the assignment is to:
#
# - format the book text into a set of training data
# - define a RNN model in Keras based on one or more LSTM or GRU layers
# - train the model with the training data
# - use the trained model to generate new text
#
# Our previous model based on Obama's essay was prone to overfitting since there was not that much data to learn from. Thus, the generated text was either unintelligeable (not enough learning) or exactly replicated the training data (over-fitting). In this case, we are working with a much bigger data set, which should provide enough data to avoid over-fitting, but will also take more time to train. To improve your model, you can experiment with tuning the following hyper-parameters:
#
# - Use more than one recurrent layer and/or add more memory units (hidden neurons) to each layer. This will allow you to learn more complex structures in the data.
# - Use sequences longer than 100 characters, which will allow you to learn from patterns further back in time.
# - Change the way the sequences are generated. For example you could try to break up the text into real sentances using the periods, and then either cut or pad each sentance to make it 100 characters long.
# - Increase the number of training epochs, which will give the model more time to learn. Monitor the validation loss at each epoch to make sure the model is still improving at each epoch and is not overfitting the training data.
# - Add more dropout to the recurrent layers to minimize over-fitting.
# - Tune the batch size - try a batch size of 1 as a (very slow) baseline and larger sizes from there.
# - Experiment with scale factors (temperature) when interpreting the prediction probabilities.
#
# If you get an error such as `alloc error` or `out of memory error` during training it means that  your computer does not have enough RAM memory to store the model parameters or the batch of training data needed during a training step. If you run into this issue, try reducing the complexity of your model (both number and depth of layers) or the mini-batch size.
#
# The last three code blocks will use your trained model to generate a sequence of text based on a predefined seed. Do not change any of the code, but run it before submitting your assignment. Your work will be evaluated based on the quality of the generated text. A good result should be legible with decent grammar and spelling (this indicates a high level of learning), but the exact text should not be found anywhere in the actual text (this indicates over-fitting).
#
# Let's start by importing the libraries we will be using, and importing the full text from Alice in Wonderland:

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

from time import gmtime, strftime
import os
import re
import pickle
import random
import sys
# Out:
# Using TensorFlow backend.

# %%
filename = "data/wonderland.txt"
raw_text = open(filename).read()

raw_text = re.sub('[^\nA-Za-z0-9 ,.:;?!-]+', '', raw_text)
raw_text = raw_text.lower()

n_chars = len(raw_text)
print "length of text:", n_chars
print "text preview:", raw_text[:500]
# Out:
# length of text: 141266
# text preview: alices adventures in wonderland
#
# lewis carroll
#
# the millennium fulcrum edition 3.0
#
#
#
#
# chapter i. down the rabbit-hole
#
# alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into the
# book her sister was reading, but it had no pictures or conversations in
# it, and what is the use of a book, thought alice without pictures or
# conversations?
#
# so she was considering in her own mind as well as she could, for the
# hot day mad

# %%
chars = sorted(list(set(raw_text)))
n_vocab = len(chars)
print "number of unique characters found:", n_vocab

# create mapping of characters to integers and back
#create dictionary of characters and numbers
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# test our mapping
print 'a', "- maps to ->", char_to_int["a"]
print 25, "- maps to ->", int_to_char[25]
# Out:
# number of unique characters found: 37
# a - maps to -> 11
# 25 - maps to -> o

# %%
seq_length = 110

inputs = []
outputs = []

for i in range(0, n_chars - seq_length, 1):
    inputs.append(raw_text[i:i + seq_length])
    outputs.append(raw_text[i + seq_length])
    
n_sequences = len(inputs)
print "Total sequences: ", n_sequences
indeces = range(len(inputs))
random.shuffle(indeces)

inputs = [inputs[x] for x in indeces]
outputs = [outputs[x] for x in indeces]
print inputs[0], "-->", outputs[0]
# Out:
# Total sequences:  141156
# h into the garden with one eye; but to get through was more
# hopeless than ever: she sat down and began to cry  --> a

# %%
X = np.zeros((n_sequences, seq_length, n_vocab), dtype=np.bool)
y = np.zeros((n_sequences, n_vocab), dtype=np.bool)


for i, example in enumerate(inputs):
    for t, char in enumerate(example):
        X[i, t, char_to_int[char]] = 1
    y[i, char_to_int[outputs[i]]] = 1
    
print 'X dims -->', X.shape
print 'y dims -->', y.shape
# Out:
# X dims --> (141156, 110, 37)
# y dims --> (141156, 37)

# %%
model = Sequential()
model.add(LSTM(32, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.40))
model.add(LSTM(32))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %% [markdown]
# **Do not change this code, but run it before submitting your assignment to generate the results**

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate(sentence, sample_length=50, diversity=0.35):
    generated = sentence
    sys.stdout.write(generated)

    for i in range(sample_length):
        x = np.zeros((1, X.shape[1], X.shape[2]))
        for t, char in enumerate(sentence):
            x[0, t, char_to_int[char]] = 1.

        preds = model.predict(x, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = int_to_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()

# %%
filepath="-advanced_LSTM.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
prediction_length = 500

epochs = 55

for iteration in range(epochs):
    
    print 'epoch:', iteration + 1, '/', epochs
    model.fit(X, y, validation_split=0.2, batch_size=250, nb_epoch=1, callbacks=callbacks_list)
    
   
    start_index = random.randint(0, len(raw_text) - seq_length - 1)
    
    seed = raw_text[start_index: start_index + seq_length]
    
    
    
    print 'generating with seed:', seed
    
    generate(seed, prediction_length, 0.5)
# Out:
# epoch: 1 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 336s - loss: 3.0025 - val_loss: 2.9064
# generating with seed:  find a pleasure in all their simple joys,
# remembering her own child-life, and the happy summer days.
#
#
#  find a pleasure in all their simple joys,
# remembering her own child-life, and the happy summer days.
#
#         neea n r te i at e e  r nae eet  tt aia  eo nte  ns  aa ho ne slee sann  at  gea t   a a g yie sae   ioyaaorhte  an a iefnetoyia a  tie hi n wu  i shee yi t  e sae, r t  ne ate o im s gr aw t
# e  e o e e ish a a a  iad t re es  et a  a eeto  o sw ni  ys ses elme ue  lh - ia n hda   t e   oef lo o   lee ab toe  ni ah iwr o th   a th
# o  t  o  eno oe t e moee oat,eahat
# se to
# tto   t ree ioo  gtae ab  e  t eee  ah  o she in t  th  hso itea a h ise h    ige o  wie e e aeo go ss , hd  e e nre oatepoch: 2 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 352s - loss: 2.7256 - val_loss: 2.5277
# generating with seed: fore she gave her
# answer. theyre done with blacking, i believe.
#
# boots and shoes under the sea, the gryphon we
# fore she gave her
# answer. theyre done with blacking, i believe.
#
# boots and shoes under the sea, the gryphon wemals t the the nhi sint to aad ant the hhe mant to the the she the the nte anme to hat see iint a a t er en b a do og ma no oi fe ce w rod iad s l e in des th r ne e ree dn l  ece n lut e a l  eid e a the y d ad tare mh che af sete co a be the the so od wu tin tee e ne d ae we wede d te the see ne te can
# p eod n t he t  np ta we no te it l c tee la nnre t e d
# el yae s nte c itade  t en te an dnd oay he the l the dead w he t nw oh paoe no te vor at e u  fe cin a thed et  o e ie nt onn
# ke i id  epoch: 3 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 354s - loss: 2.4884 - val_loss: 2.3708
# generating with seed: d the knave of hearts, carrying the kings
# crown on a crimson velvet cushion; and, last of all this grand
# proce
# d the knave of hearts, carrying the kings
# crown on a crimson velvet cushion; and, last of all this grand
# proce an ghe ther at ice sor ant she the an cou the sout an shag war the she ant ho the the the woot sere sore the te the poe anr at the ghe toe whe her wout anl dore the ans ant so is the or the the to she sour oo so tace, tour, an he the alt the wan ita lo the wor the shans in so saco cone an anp to tor tous ther an the sok an the the oo the ohe in the anc in in she anl anr nher ing ans the the alt yo the the younw ert an mere sot the ace and cont eot oor the at aun an the
# yhe ans it on the bin theepoch: 4 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 356s - loss: 2.3811 - val_loss: 2.2882
# generating with seed: a
# that they must be collected at once and put back into the jury-box, or
# they would die.
#
# the trial cannot pro
# a
# that they must be collected at once and put back into the jury-box, or
# they would die.
#
# the trial cannot prous an the fout ol the and anle and an ther anthe, lore lore nat ank anr the and out the the oo the af if the ore she yat in the foun the ange
# the the in he the oult it sat to the
# he she sot the banre
# and the whind in he the the the to ther ant ant to she the the ang han woud o see she rothe the won oud sein l          l            f                                                                          u
#       he         e                                   epoch: 5 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 355s - loss: 2.3125 - val_loss: 2.2405
# generating with seed: e fun now! thought alice. im glad theyve
# begun asking riddles.--i believe i can guess that, she added aloud.
#
#
# e fun now! thought alice. im glad theyve
# begun asking riddles.--i believe i can guess that, she added aloud.
#
# an be noud o the and oud the as in the the wound mas the baghe suic the wons whos so so sor the cang and hat the sale soo the wer alise
# she ount to her soo to out the woud an she and she sher so cat sle wad the dang the sins wor the soe sut rethe anp the the whe wer the at the war the the the at thace tor at the soud the thit the the the the the seer sat the ald to sound all the the the the the tor souf the boud the to souge the thibe the pore the the ans and an the se boud and the, sor the the epoch: 6 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 352s - loss: 2.2626 - val_loss: 2.1881
# generating with seed: ow without
# knowing how old it was, and, as the lory positively refused to tell its
# age, there was no more to b
# ow without
# knowing how old it was, and, as the lory positively refused to tell its
# age, there was no more to boud ane ang the nepe har ther the bang hounnd wor hat the the bace wat the the wang was and wats the the mat more the ould in wird she sot cerance her the the ad here houd ant at to the sut and brat in see woud bat same eshe wor gon wering so the cadlins mow in the ther
# wore ad the wore the ind and her the sore the the gat the ale the nere ant and ale il ant her was the she were the sore ant tail and i sit the the and bow ther and the can poer, the to of mougend an in she core wet the aren the qepoch: 7 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] -
/ 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 348s - loss: 2.0989 - val_loss: 2.0281
# generating with seed: h, tell me the truth:
# did you ever eat a bat? when suddenly, thump! thump! down she came upon
# a heap of sticks
# h, tell me the truth:
# did you ever eat a bat? when suddenly, thump! thump! down she came upon
# a heap of stickser lorted the the gas in the har the and the the case whes she sale, the the cathed her hard matte thoud the cowt on the tree for the have of to sa coure who the ham on in bow a fertey it the gere the mat to the dore sore cound the to hax to the mouce to the at at the tat the wast and gat and as the courd the cork the got with the gat it it the wert at a dound and the to say the the wert reren a soud the a come alice sow on the ore be cate the wat with the dat the gas be chas the and to dound anepoch: 13 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 348s - loss: 2.0794 - val_loss: 2.0088
# generating with seed: ats eat cats? for, you see, as she couldnt answer either question,
# it didnt much matter which way she put it.
# ats eat cats? for, you see, as she couldnt answer either question,
# it didnt much matter which way she put it. the of that of bepong thing in the pase a bough she gem a it in in a har the mare the mish behend it the the count a the queen the ang the wert ont of her the bat her the sate could her alime, and her saod of a her the gong madten there the colle
# one she and hers alice the had in the rathed il ittang and in and the dopt and the wa he ane a suren of the gound the cound the to the the and and the ceat of the with a bepangen-she couthed a cat in the all and mover was wat the gort and the cas alite epoch: 14 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 347s - loss: 2.0623 - val_loss: 1.9893
# generating with seed:  alice.
#
# and ever since that, the hatter went on in a mournful tone, he wont
# do a thing i ask! its always six
#  alice.
#
# and ever since that, the hatter went on in a mournful tone, he wont
# do a thing i ask! its always six the aid the hanged as the got of she doon the dole founs of how in begh veroulg and a cound when it said the dotter the wankling counged the seing fouls alick thee sout when whet whan tall a the sore whan the caster the ceat a dound of the core dow mower i dorrell to
# the wam the core.
#
# in in the when in in the the hor a her and she was and found wat a lis of the kale wat as the queen.
#
# the cat the citemerenle, she the gons a on the the rowed and the how in the wore her wat the sat and hersent ofepoch: 15 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 348s - loss: 2.0461 - val_loss: 1.9721
# generating with seed: d anxiously to herself, which way? which
# way?, holding her hand on the top of her head to feel which way it wa
# d anxiously to herself, which way? which
# way?, holding her hand on the top of her head to feel which way it was noud the doke the powing and the sisece in she to her sele feres a deoply bint at the door the soeted in the shitet ald and the turce the bowed tale ale the core, she ound and the kough it the cale of aping the gas in the mome of at and a dad the coudted the cast, the the mowere her i the pourd wat a is a count in the cas the mast in at in alice and the catting the to lorked the rotger and to the kein a her could thace to her the tutre of arice the herser and the arice a the catted to and the epoch: 16 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 372s - loss: 2.0332 - val_loss: 1.9633
# generating with seed: er minute the whole head appeared, and then alice put
# down her flamingo, and began an account of the game, fee
# er minute the whole head appeared, and then alice put
# down her flamingo, and began an account of the game, fee be a gor a cothe be the mist her dadter the she mowes and and the to hat a i durttling you the sale.
#
# a dees thougen alice sise the hat fow and the hars the wan the kalk alice whel the king
# alice a the tilt who the haghed a coull hatter the turt she rowe har of the gat in thoud the sain a fit dow she see it at and so the was a the wrose alice pale the dich fare and lowt she to so the mare the went a bether in the said the wat a dis darce the counger, said and the matk wat the the core the cas aepoch: 17 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 352s - loss: 2.0181 - val_loss: 1.9504
# generating with seed: u.--come,
#            ill take no
#            denial; we
#           must have a
#         trial: for
#       really t
# u.--come,
#            ill take no
#            denial; we
#           must have a
#         trial: for
#       really the durh a
#                                                                                                                                           epoch: 18 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 350s - loss: 2.0048 - val_loss: 1.9317
# generating with seed: h his
# head!
#
# how dreadfully savage! exclaimed alice.
#
# and ever since that, the hatter went on in a mournful to
# h his
# head!
#
# how dreadfully savage! exclaimed alice.
#
# and ever since that, the hatter went on in a mournful to hat the root wher to the got a been her cas the ga bettle thited be the out and meos mow of a popce her had wat she tale the grock noked sale to she gere.
#
# a with whound the moung the darnt of so the cound and of she poot in the kerked the crowt, she cound the gon and hor she to her deanged she kine, and nout it she alice alice it ive in alice said core in the gris the wout the hars a cous, and the sisken rother the rittle the to mish all of the gor of and ot a to so had the queen the bower allepoch: 19 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 347s - loss: 1.9926 - val_loss: 1.9181
# generating with seed: t the flame of a
# candle is like after the candle is blown out, for she could not remember
# ever having seen suc
# t the flame of a
# candle is like after the candle is blown out, for she could not remember
# ever having seen such be and said core wat see core it to she cow of what the wat the cound the begh down the queen the king the could har the coud in and alice and the cought the kneansed has the wat hertelf her had all she grrow wo her her of the coult a her and of the sale out the koon the erome the hard and the certert that the deat who has nean the mowh a ceonten the dlaten in the matked bound and curte the cound the cat the count a dean the dacge wat it and the doon the kerang to the mathed the the wat purterepoch: 20 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 349s - loss: 1.9827 - val_loss: 1.9085
# generating with seed:  i should think youll feel it a little
# queer, wont you?
#
# not a bit, said the caterpillar.
#
# well, perhaps your
#  i should think youll feel it a little
# queer, wont you?
#
# not a bit, said the caterpillar.
#
# well, perhaps your the histtly the gap the been bet the pont the ank all the was as the case to be you ther to her had the terse, she herser the pareg the pase and the marge of the cont the dasked the dis the the root the hare of the dound when the say of the wound was the dat the king weat the courle rat the said a cather the gat the co sise sis the got the caster the corbe tilt alone the queired wald a one the wat she come and the the morked was and the you klead in of the reong to the rowt alice the pore all reepoch: 21 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 347s - loss: 1.9714 - val_loss: 1.8975
# generating with seed: it-hole
#
# alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to
# it-hole
#
# alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to the kerant the hor her sead the song wher alice the cat the kid in the got wher wat and were the casd dore to said the gran you peas the darded the couts of the doop un a bouther of the was a cone of the eronged to cound that to thing the doping the king, the hat a dumt on and in you the care in she curded with what, at the cowlled her all of the sint all wat her to she queen wat and the came the kall the coud, she meant hor there the chisters of her coon so chome of it it it a sout the castle tepoch: 22 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 346s - loss: 1.9613 - val_loss: 1.8929
# generating with seed: nd it as far as they would go, and broke off a bit
# of the edge with each hand.
#
# and now which is which? she sa
# nd it as far as they would go, and broke off a bit
# of the edge with each hand.
#
# and now which is which? she said the had the gat of what the wat the queet a catter to the elich the gartly of hat it and the gor the gat her the croked the got a the mitered her wale the that the
# queen the hissing her the as to she ang the gon that and the was the cant a the grean in the gry to she dorder the king it her the queen her cound the the dong what hid in the cant it a to lode out be har the alice the rant the dowt wat the sreaned the to the dorger the mace wong at in the dusting alice so mepten the coud wat then epoch: 23 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] -
/ 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 347s - loss: 1.8458 - val_loss: 1.7781
# generating with seed: idnt! interrupted alice.
#
# you did, said the mock turtle.
#
# hold your tongue! added the gryphon, before alice co
# idnt! interrupted alice.
#
# you did, said the mock turtle.
#
# hold your tongue! added the gryphon, before alice courted of a mowped the latter the could the came it the gryat, and the like the kard the came the cate insher the mistle the gont of her and the mowed the cound the mach a latteg the doon an see it the you the catter the could to she hat it deen it as the mistle the was the mippered the little the doon all at she was and the mood of the kily of the mide the might to she said her was it of the cerke the grarton a little the hamter, and the kall the fortle would to the kid a the dims what to the goepoch: 41 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 349s - loss: 1.8449 - val_loss: 1.7751
# generating with seed: tory.
#
# im afraid i dont know one, said alice, rather alarmed at the
# proposal.
#
# then the dormouse shall! they b
# tory.
#
# im afraid i dont know one, said alice, rather alarmed at the
# proposal.
#
# then the dormouse shall! they begen a cated the ratter all a mood and the didly in the dogt on the queen the mary her her and the can all the romy its a lowed and the herser as and the down the mared and the gry she rad and the dorteln the cather all it all her get alice of the could to see abler that in the catter on the dool the hatter the wases on the cater of the maring the dorged the hit then ape the had the catting the can the asting off bege rowened it the cates the must a the down alice the was it what the graling, anepoch: 42 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 349s - loss: 1.8412 - val_loss: 1.7705
# generating with seed: hat! but she did not venture to say it out
# loud.
#
# thinking again? the duchess asked, with another dig of her s
# hat! but she did not venture to say it out
# loud.
#
# thinking again? the duchess asked, with another dig of her said the cance at if the wer the lave it alice, and the courter
# to she mide the gry whise the was ther had the king in alice in i parted the like who said the wheres a hit to she cropt a aloce on the doung the to could the dore her it to the mount a much it said the manked the mook the mouse, and the cat the minge the cater all the down mide in the dong at she the your, dow ont and the koon she her was in the earll his say and the was in a pont the cond us a whan she could of the dong not the mowepoch: 43 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 349s - loss: 1.8356 - val_loss: 1.7674
# generating with seed: hind to execute the unfortunate gardeners, who ran
# to alice for protection.
#
# you shant be beheaded! said alice
# hind to execute the unfortunate gardeners, who ran
# to alice for protection.
#
# you shant be beheaded! said alice, and fout the cane the down the kad in a could not of the doce she doon the its the dont the was it a aice the mowt the didsted the herse, she could to in the said the gryatull eide the was alice, and she down alice, and the cater the gryen on the mint the would the queat of one sire for the catenunt
# at the said the mone a lought in the mong the queen the catered to he said the could of the side a lead the can the could was the could the doon the hertertent and the domtain the moure to her the epoch: 44 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] - 358s - loss: 1.8310 - val_loss: 1.7617
# generating with seed: really offended. we wont talk about her any
# more if youd rather not.
#
# we indeed! cried the mouse, who was trem
# really offended. we wont talk about her any
# more if youd rather not.
#
# we indeed! cried the mouse, who was trem the mext a the door said the could at look to what amat the canery the got the down the gratle out a beting or it had then a what a preast hid very the cant the murlet and the cat furting the queen the was be har she catker the course the morgered the doon, and the wert all the mook to be butter her gatter, she mistle the whone the dong, the malice of the gryat of the row me she latter the ristly it said on could to her the kake so she ritting the doon in a dain the mowed the kids of the was thepoch: 45 / 55
# Train on 112924 samples, validate on 28232 samples
# Epoch 1/1
# 112924/112924 [==============================] -